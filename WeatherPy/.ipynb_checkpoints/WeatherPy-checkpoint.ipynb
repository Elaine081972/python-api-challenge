# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
import json 
import scipy.stats as st

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 599

# %%
cities
# Out:
# ['kitgum',
#  'bredasdorp',
#  'rikitea',
#  'iracoubo',
#  'vao',
#  'rio grande',
#  'tual',
#  'nikolskoye',
#  'ushuaia',
#  'karaul',
#  'pokrovskoye',
#  'sentyabrskiy',
#  'lebu',
#  'victoria',
#  'new norfolk',
#  'bambous virieux',
#  'zemio',
#  'mahebourg',
#  'castro',
#  'sola',
#  'saint george',
#  'carnarvon',
#  'ust-kuyga',
#  'haileybury',
#  'pozo colorado',
#  'avarua',
#  'shingu',
#  'grindavik',
#  'severo-kurilsk',
#  'lorengau',
#  'saint-philippe',
#  'arraial do cabo',
#  'leningradskiy',
#  'kavaratti',
#  'vila velha',
#  'puerto ayora',
#  'illoqqortoormiut',
#  'barentsburg',
#  'bengkulu',
#  'ust-nera',
#  'hilo',
#  'kandrian',
#  'clyde river',
#  'hermanus',
#  'souillac',
#  'baker city',
#  'wahlern',
#  'longyearbyen',
#  'punta arenas',
#  'alice springs',
#  'tete',
#  'rawson',
#  'initao',
#  'monterrey',
#  'petropavlovsk-kamchatskiy',
#  'omboue',
#  'ryotsu',
#  'cap malheureux',
#  'olafsvik',
#  'port alfred',
#  'ribeira grande',
#  'poum',
#  'ulladulla',
#  'cascais',
#  'cabo san lucas',
#  'busselton',
#  'belushya guba',
#  'guerrero negro',
#  'cape town',
#  'komsomolskiy',
#  'portland',
#  'sinazongwe',
#  'saskylakh',
#  'mataura',
#  'sitka',
#  'kapaa',
#  'tsihombe',
#  'port lincoln',
#  'hobart',
#  'labuhan',
#  'atar',
#  'altamira',
#  'riverton',
#  'nyzhni sirohozy',
#  'hithadhoo',
#  'taolanaro',
#  'jamestown',
#  'esperance',
#  'nanortalik',
#  'airai',
#  'aksarka',
#  'warrington',
#  'fairbanks',
#  'tuktoyaktuk',
#  'haverfordwest',
#  'flinders',
#  'mingaora',
#  'tornio',
#  'amderma',
#  'brunswick',
#  'bluff',
#  'sambava',
#  'coquimbo',
#  'hasaki',
#  'thompson',
#  'beloha',
#  'sangar',
#  'atuona',
#  'saleaula',
#  'provideniya',
#  'tawkar',
#  'vaitupu',
#  'acapulco',
#  'butaritari',
#  'grand gaube',
#  'nizhneyansk',
#  'berlevag',
#  'katsuura',
#  'yerbogachen',
#  'sydney mines',
#  'linhares',
#  'zholymbet',
#  'tumannyy',
#  'iznoski',
#  'ballina',
#  'palu',
#  'faanui',
#  'dikson',
#  'den helder',
#  'tautira',
#  'kankavli',
#  'ipira',
#  'benguela',
#  'assiniboia',
#  'buraydah',
#  'salalah',
#  'cidreira',
#  'upernavik',
#  'caravelas',
#  'pevek',
#  'half moon bay',
#  'east london',
#  'dushanbe',
#  'barrow',
#  'villa rica',
#  'tarare',
#  'kahului',
#  'narsaq',
#  'mys shmidta',
#  'karratha',
#  'dovbysh',
#  'revda',
#  'taburi',
#  'havoysund',
#  'paracuru',
#  'westport',
#  'lodja',
#  'dongsheng',
#  'mandalgovi',
#  'oudtshoorn',
#  'ciudad bolivar',
#  'miles city',
#  'the valley',
#  'kununurra',
#  'chunskiy',
#  'la ronge',
#  'borazjan',
#  'praia',
#  'nago',
#  'namatanai',
#  'novyy urengoy',
#  'altay',
#  'vaini',
#  'tilichiki',
#  'santa marinella',
#  'tongren',
#  'mar del plata',
#  'ahipara',
#  'koulikoro',
#  'lagos',
#  'syracuse',
#  'kruisfontein',
#  'donskoye',
#  'kuusamo',
#  'lompoc',
#  'eyl',
#  'mugur-aksy',
#  'roros',
#  'namibe',
#  'charters towers',
#  'port elizabeth',
#  'basco',
#  'coihaique',
#  'lisakovsk',
#  'chapais',
#  'aasmae',
#  'marystown',
#  'knysna',
#  'fortuna',
#  'cherskiy',
#  'chokurdakh',
#  'shimoda',
#  'nantucket',
#  'nome',
#  'qaanaaq',
#  'cukai',
#  'pampas',
#  'pimenta bueno',
#  'takoradi',
#  'aklavik',
#  'khandagayty',
#  'albany',
#  'wilmington',
#  'dali',
#  'pitea',
#  'samusu',
#  'north bend',
#  'chernyshevskiy',
#  'punta cardon',
#  'san policarpo',
#  'kirakira',
#  'yumen',
#  'laguna',
#  'necochea',
#  'jurm',
#  'vanimo',
#  'dabeiba',
#  'egvekinot',
#  'beringovskiy',
#  'balkanabat',
#  'qaqortoq',
#  'tidore',
#  'kazalinsk',
#  'fayaoue',
#  'bathsheba',
#  'magnolia',
#  'caxito',
#  'novogagatli',
#  'chitipa',
#  'norman wells',
#  'villacarrillo',
#  'tall kayf',
#  'vaitape',
#  'saldanha',
#  'tifton',
#  'pointe michel',
#  'sinkat',
#  'pangnirtung',
#  'harper',
#  'karakendzha',
#  'west fargo',
#  'ponta do sol',
#  'kerman',
#  'jatai',
#  'havre-saint-pierre',
#  'bandarbeyla',
#  'valparaiso',
#  'bahia blanca',
#  'isangel',
#  'georgetown',
#  'parana',
#  'champerico',
#  'sindand',
#  'gangotri',
#  'palabuhanratu',
#  'khatanga',
#  'tasiilaq',
#  'moron',
#  'alofi',
#  'dunedin',
#  'hami',
#  'iskateley',
#  'savalou',
#  'hammerfest',
#  'ereymentau',
#  'birobidzhan',
#  'cururupu',
#  'sherlovaya gora',
#  'nouakchott',
#  'baykit',
#  'yachimata',
#  'paita',
#  'flin flon',
#  'sisimiut',
#  'andenes',
#  'puerto escondido',
#  'phan rang',
#  'lagoa',
#  'bargteheide',
#  'talnakh',
#  'sabang',
#  'klaksvik',
#  'mackenzie',
#  'adre',
#  'tiksi',
#  'daphne',
#  'paijan',
#  'ati',
#  'alexandria',
#  'otane',
#  'torbay',
#  'bethel',
#  'qasigiannguit',
#  'meulaboh',
#  'avera',
#  'padang',
#  'hamilton',
#  'shache',
#  'kijang',
#  'ilulissat',
#  'talara',
#  'san bartolome de tirajana',
#  'vilcun',
#  'gombong',
#  'minsk',
#  'pacific grove',
#  'santona',
#  'kamenka',
#  'kolosovka',
#  'kushchevskaya',
#  'cumaribo',
#  'nagato',
#  'nenjiang',
#  'tlachichuca',
#  'iranshahr',
#  'iquique',
#  'linkoping',
#  'male',
#  'narasannapeta',
#  'griffith',
#  'yellowknife',
#  'roma',
#  'igarka',
#  'haines junction',
#  'tabuk',
#  'itarema',
#  'darnah',
#  'kyra',
#  'saint-joseph',
#  'key west',
#  'ust-uda',
#  'pontes e lacerda',
#  'kinel-cherkassy',
#  'iqaluit',
#  'long xuyen',
#  'kaitangata',
#  'pamplona',
#  'sabya',
#  'waldoboro',
#  'usinsk',
#  'yola',
#  'la reforma',
#  'aripuana',
#  'umm kaddadah',
#  'seoul',
#  'moa',
#  'kaseda',
#  'ermelo',
#  'northam',
#  'pauini',
#  'turka',
#  'shellbrook',
#  'chifeng',
#  'vardo',
#  'codrington',
#  'gladstone',
#  'sorsk',
#  'xuddur',
#  'aplahoue',
#  'eenhana',
#  'fukue',
#  'bograd',
#  'kovdor',
#  'vostok',
#  'robat karim',
#  'college',
#  'kavieng',
#  'tuatapere',
#  'constitucion',
#  'te anau',
#  'muros',
#  'nelson bay',
#  'cayenne',
#  'asau',
#  'bunia',
#  'san cristobal',
#  'grand-santi',
#  'colares',
#  'visnes',
#  'asfi',
#  'copiapo',
#  'turayf',
#  'mullaitivu',
#  'pisco',
#  'huarmey',
#  'navirai',
#  'hobyo',
#  'tahoua',
#  'otradnoye',
#  'armidale',
#  'los llanos de aridane',
#  'imbituba',
#  'noumea',
#  'hambantota',
#  'solnechnyy',
#  'biograd na moru',
#  'acarau',
#  'pepel',
#  'sahrak',
#  'koutiala',
#  'manadhoo',
#  'methven',
#  'ust-kamchatsk',
#  'baracoa',
#  'nueva italia de ruiz',
#  'salina cruz',
#  'panaba',
#  'deputatskiy',
#  'bembereke',
#  'loncoche',
#  'saint-pierre',
#  'dingle',
#  'stoyba',
#  'oksfjord',
#  'america dourada',
#  'vredendal',
#  'rungata',
#  'talakan',
#  'savonlinna',
#  'cam ranh',
#  'aykhal',
#  'magadan',
#  'filingue',
#  'verkhnyaya inta',
#  'sorong',
#  'along',
#  'touros',
#  'tura',
#  'brezice',
#  'zlitan',
#  'marcona',
#  'kindu',
#  'yulara',
#  'opuwo',
#  'port hardy',
#  'chuy',
#  'maldonado',
#  'dickinson',
#  'mahajanga',
#  'chamrajnagar',
#  'nyahururu',
#  'mendahara',
#  'adrar',
#  'verkhnyaya toyma',
#  'dhidhdhoo',
#  'ribas do rio pardo',
#  'gravdal',
#  'mutis',
#  'kodiak',
#  'kostomuksha',
#  'bowen',
#  'fare',
#  'cuamba',
#  'niteroi',
#  'urengoy',
#  'macas',
#  'siilinjarvi',
#  'ambon',
#  'uglegorskiy',
#  'crab hill',
#  'angoche',
#  'ponta delgada',
#  'miraflores',
#  'byron bay',
#  'tocopilla',
#  'nabire',
#  'kanganpur',
#  'yadrin',
#  'toliary',
#  'ossora',
#  'pasni',
#  'thinadhoo',
#  'nishihara',
#  'misawa',
#  'kabare',
#  'muisne',
#  'hervey bay',
#  'los alamos',
#  'cocachacra',
#  'margate',
#  'wanning',
#  'birao',
#  'nuuk',
#  'santa maria da boa vista',
#  'marsh harbour',
#  'meyungs',
#  'ishigaki',
#  'port hedland',
#  'kurilsk',
#  'pandan',
#  'sao filipe',
#  'mitsamiouli',
#  'mizdah',
#  'henties bay',
#  'tuggurt',
#  'anadyr',
#  'arlit',
#  'huazolotitlan',
#  'puerto maldonado',
#  'aksu',
#  'praia da vitoria',
#  'zaoyang',
#  'abashiri',
#  'faya',
#  'yasnyy',
#  'stokmarknes',
#  'najran',
#  'pokhara',
#  'mackay',
#  'ambovombe',
#  'mattru',
#  'naze',
#  'san patricio',
#  'ganzhou',
#  'luderitz',
#  'znamenskoye',
#  'manta',
#  'rio gallegos',
#  'coahuayana',
#  'biak',
#  'biskamzha',
#  'akola',
#  'nieuw amsterdam',
#  'uslar',
#  'umzimvubu',
#  'wajir',
#  'lakes entrance',
#  'lasa',
#  'sfantu gheorghe',
#  'gushikawa',
#  'grand river south east',
#  'fergus falls',
#  'broome',
#  'parrsboro',
#  'vestmannaeyjar',
#  'sandpoint',
#  'belmonte',
#  'morros',
#  'le moule',
#  'changji',
#  'balykshi',
#  'olesno',
#  'mount gambier',
#  'mayya',
#  'ngukurr',
#  'korla',
#  'taoudenni',
#  'bima',
#  'latung',
#  'bubaque',
#  'calan',
#  'mimongo',
#  'djambala',
#  'gorontalo',
#  'pingliang',
#  'manaure',
#  'salina',
#  'mayo',
#  'cazaje',
#  'bhatkal',
#  'attawapiskat',
#  'metro',
#  'caruray',
#  'trenggalek',
#  'karpathos',
#  'ao luk',
#  'umm jarr',
#  'jayanca',
#  'hirara',
#  'hirado',
#  'quatre cocos',
#  'hovd',
#  'beni suef',
#  'prince rupert',
#  'joue-les-tours',
#  'zhigansk',
#  'makakilo city',
#  'vila franca do campo',
#  'burica',
#  'malumfashi',
#  'kimparana',
#  'port macquarie',
#  'poronaysk',
#  'la ciotat',
#  'dubai',
#  'sur',
#  'lata',
#  'okhotsk',
#  'bilibino']

# %%
# Save config information.
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "metric"

# Build partial query URL
query_url = f"{url}appid={weather_api_key}&units={units}&q="

# %%
# Create lists for holding information
cityname = []
lat = []
lon = []
max_temp = []
humidity = []
cloudiness = []
windspeed = []
country = []
date = []
cityid = []

# Loop through the list of cities and perform a request for data on each with try/except for handling purposes
for city in cities:
    response = requests.get(query_url + city).json()
    try:
        cityname.append(response["name"])
        lat.append(response["coord"]["lat"])
        lon.append(response["coord"]["lon"])
        max_temp.append(response["main"]["temp_max"])
        humidity.append(response["main"]["humidity"])
        cloudiness.append(response["clouds"]["all"])
        windspeed.append(response["wind"]["speed"])
        country.append(response["sys"]["country"])
        date.append(response["dt"])
        cityid.append(response["id"])
    
        print(f"The city is: {cityname} and id is: {cityid}")
       
    except:
        print("No data for that city")
        pass
# Out:
# The city is: ['Kitgum'] and id is: [230893]
# The city is: ['Kitgum', 'Bredasdorp'] and id is: [230893, 1015776]
# The city is: ['Kitgum', 'Bredasdorp', 'Rikitea'] and id is: [230893, 1015776, 4030556]
# The city is: ['Kitgum', 'Bredasdorp', 'Rikitea', 'Iracoubo'] and id is: [230893, 1015776, 4030556, 3381428]
# The city is: ['Kitgum', 'Bredasdorp', 'Rikitea', 'Iracoubo', 'Vao'] and id is: [230893, 1015776, 4030556, 3381428, 2137773]
# The city is: ['Kitgum', 'Bredasdorp', 'Rikitea', 'Iracoubo', 'Vao', 'Rio Grande'] and id is: [230893, 1015776, 4030556, 3381428, 2137773, 3451138]
# The city is: ['Kitgum', 'Bredasdorp', 'Rikitea', 'Iracoubo', 'Vao', 'Rio Grande', 'Tual'] and id is: [230893, 1015776, 4030556, 3381428, 2137773, 3451138, 1623197]
# The city is: ['Kitgum', 'Bredasdorp', 'Rikitea', 'Iracoubo', 'Vao', 'Rio Grande', 'Tual', 'Nikolskoye'] and id is: [230893, 1015776, 4030556, 3381428, 2137773, 3451138, 1623197, 546105]
# The city is: ['Kitgum', 'Bredasdorp', 'Rikitea', 'Iracoubo', 'Vao', 'Rio Grande', 'Tual', 'Nikolskoye', 'Ushuaia'] and id is: [230893, 1015776, 4030556, 3381428, 2137773, 3451138, 1623197, 546105, 3833367]
# No data for that city
# The city is: ['Kitgum', 'Bredasdorp', 'Rikitea', 'Iracoubo', 'Vao', 'Rio Grande', 'Tual', 'Nikolskoye', 'Ushuaia', 'Pokrovskoye'] and id is: [230893, 1015776, 4030556, 3381428, 2137773, 3451138, 1623197, 546105, 3833367, 507427]
# No data for that city
# The city is: ['Kitgum', 'Bredasdorp', 'Rikitea', 'Iracoubo', 'Vao', 'Rio Grande', 'Tual', 'Nikolskoye', 'Ushuaia', 'Pokrovskoye', 'Lebu'] and id is: [230893, 1015776, 4030556, 3381428, 2137773, 3451138, 1623197, 546105, 3833367, 507427, 3883457]
# The city is: ['Kitgum', 'Bredasdorp', 'Rikitea', 'Iracoubo', 'Vao', 'Rio Grande', 'Tual', 'Nikolskoye', 'Ushuaia', 'Pokrovskoye', 'Lebu', 'Hong Kong'] and id is: [230893, 1015776, 4030556, 3381428, 2137773, 3451138, 1623197, 546105, 3833367, 507427, 3883457, 1819729]
# The city is: ['Kitgum', 'Bredasdorp', 'Rikitea', 'Iracoubo', 'Vao', 'Rio Grande', 'Tual', 'Nikolskoye', 'Ushuaia', 'Pokrovskoye', 'Lebu', 'Hong Kong', 'New Norfolk'] and id is: [230893, 1015776, 4030556, 3381428, 2137773, 3451138, 1623197, 546105, 3833367, 507427, 3883457, 1819729, 2155415]
# The city is: ['Kitgum', 'Bredasdorp', 'Rikitea', 'Iracoubo', 'Vao', 'Rio Grande', 'Tual', 'Nikolskoye', 'Ushuaia', 'Pokrovskoye', 'Lebu', 'Hong Kong', 'New Norfolk', 'Bambous Virieux'] and id is: [230893, 1015776, 4030556, 3381428, 2137773, 3451138, 1623197, 546105, 3833367, 507427, 3883457, 1819729, 2155415, 1106677]
# The city is: ['Kitgum', 'Bredasdorp', 'Rikitea', 'Iracoubo', 'Vao', 'Rio Grande', 'Tual', 'Nikolskoye', 'Ushuaia', 'Pokrovskoye', 'Lebu', 'Hong Kong', 'New Norfolk', 'Bambous Virieux', 'Zemio'] and id is: [230893, 1015776, 4030556, 3381428, 2137773, 3451138, 1623197, 546105, 3833367, 507427, 3883457, 1819729, 2155415, 1106677, 235826]
# The city is: ['Kitgum', 'Bredasdorp', 'Rikitea', 'Iracoubo', 'Vao', 'Rio Grande', 'Tual', 'Nikolskoye', 'Ushuaia', 'Pokrovskoye', 'Lebu', 'Hong Kong', 'New Norfolk', 'Bambous Virieux', 'Zemio', 'Mahébourg'] and id is: [230893, 1015776, 4030556, 3381428, 2137773, 3451138, 1623197, 546105, 3833367, 507427, 3883457, 1819729, 2155415, 1106677, 235826, 934322]
# The city is: ['Kitgum', 'Bredasdorp', 'Rikitea', 'Iracoubo', 'Vao', 'Rio Grande', 'Tual', 'Nikolskoye', 'Ushuaia', 'Pokrovskoye', 'Lebu', 'Hong Kong', 'New Norfolk', 'Bambous Virieux', 'Zemio', 'Mahébourg', 'Castro'] and id is: [230893, 1015776, 4030556, 3381428, 2137773, 3451138, 1623197, 546105, 3833367, 507427, 3883457, 1819729, 2155415, 1106677, 235826, 934322, 3466704]
# The city is: ['Kitgum', 'Bredasdorp', 'Rikitea', 'Iracoubo', 'Vao', 'Rio Grande', 'Tual', 'Nikolskoye', 'Ushuaia', 'Pokrovskoye', 'Lebu', 'Hong Kong', 'New Norfolk', 'Bambous Virieux', 'Zemio', 'Mahébourg', 'Castro', 'Sola'] and id is: [230893, 1015776, 4030556, 3381428, 2137773, 3451138, 1623197, 546105, 3833367, 507427, 3883457, 1819729, 2155415, 1106677, 235826, 934322, 3466704, 2134814]
# The city is: ['Kitgum', 'Bredasdorp', 'Rikitea', 'Iracoubo', 'Vao', 'Rio Grande', 'Tual', 'Nikolskoye', 'Ushuaia', 'Pokrovskoye', 'Lebu', 'Hong Kong', 'New Norfolk', 'Bambous Virieux', 'Zemio', 'Mahébourg', 'Castro', 'Sola', 'Saint George'] and id is: [230893, 1015776, 4030556, 3381428, 2137773, 3451138, 1623197, 546105, 3833367, 507427, 3883457, 1819729, 2155415, 1106677, 235826, 934322, 3466704, 2134814, 5546220]
# The city is: ['Kitgum', 'Bredasdorp', 'Rikitea', 'Iracoubo', 'Vao', 'Rio Grande', 'Tual', 'Nikolskoye', 'Ushuaia', 'Pokrovskoye', 'Lebu', 'Hong Kong', 'New Norfolk', 'Bambous Virieux', 'Zemio', 'Mahébourg', 'Castro', 'Sola', 'Saint George', 'Carnarvon'] and id is: [230893, 1015776, 4030556, 3381428, 2137773, 3451138, 1623197, 546105, 3833367, 507427, 3883457, 1819729, 2155415, 1106677, 235826, 934322, 3466704, 2134814, 5546220, 2074865]
# The city is: ['Kitgum', 'Bredasdorp', 'Rikitea', 'Iracoubo', 'Vao', 'Rio Grande', 'Tual', 'Nikolskoye', 'Ushuaia', 'Pokrovskoye', 'Lebu', 'Hong Kong', 'New Norfolk', 'Bambous Virieux', 'Zemio', 'Mahébourg', 'Castro', 'Sola', 'Saint George', 'Carnarvon', 'Ust-Kuyga'] and id is: [230893, 1015776, 4030556, 3381428, 2137773, 3451138, 1623197, 546105, 3833367, 507427, 3883457, 1819729, 2155415, 1106677, 235826, 934322, 3466704, 2134814, 5546220, 2074865, 2013921]
# The city is: ['Kitgum', 'Bredasdorp', 'Rikitea', 'Iracoubo', 'Vao', 'Rio Grande', 'Tual', 'Nikolskoye', 'Ushuaia', 'Pokrovskoye', 'Lebu', 'Hong Kong', 'New Norfolk', 'Bambous Virieux', 'Zemio', 'Mahébourg', 'Castro', 'Sola', 'Saint George', 'Carnarvon', 'Ust-Kuyga', 'Haileybury'] and id is: [230893, 1015776, 4030556, 3381428, 2137773, 3451138, 1623197, 546105, 3833367, 507427, 3883457, 1819729, 2155415, 1106677, 235826, 934322, 3466704, 2134814, 5546220, 2074865, 2013921, 5968992]
# The city is: ['Kitgum', 'Bredasdorp', 'Rikitea', 'Iracoubo', 'Vao', 'Rio Grande', 'Tual', 'Nikolskoye', 'Ushuaia', 'Pokrovskoye', 'Lebu', 'Hong Kong', 'New Norfolk', 'Bambous Virieux', 'Zemio', 'Mahébourg', 'Castro', 'Sola', 'Saint George', 'Carnarvon', 'Ust-Kuyga', 'Haileybury', 'Pozo Colorado'] and id is: [230893, 1015776, 4030556, 3381428, 2137773, 3451138, 1623197, 546105, 3833367, 507427, 3883457, 1819729, 2155415, 1106677, 235826, 934322, 3466704, 2134814, 5546220, 2074865, 2013921, 5968992, 3437443]
# The city is: ['Kitgum', 'Bredasdorp', 'Rikitea', 'Iracoubo', 'Vao', 'Rio Grande', 'Tual', 'Nikolskoye', 'Ushuaia', 'Pokrovskoye', 'Lebu', 'Hong Kong', 'New Norfolk', 'Bambous Virieux', 'Zemio', 'Mahébourg', 'Castro', 'Sola', 'Saint George', 'Carnarvon', 'Ust-Kuyga', 'Haileybury', 'Pozo Colorado', 'Avarua'] and id is: [230893, 1015776, 4030556, 3381428, 2137773, 3451138, 1623197, 546105, 3833367, 507427, 3883457, 1819729, 2155415, 1106677, 235826, 934322, 3466704, 2134814, 5546220, 2074865, 2013921, 5968992, 3437443, 4035715]
# The city is: ['Kitgum', 'Bredasdorp', 'Rikitea', 'Iracoubo', 'Vao', 'Rio Grande', 'Tual', 'Nikolskoye', 'Ushuaia', 'Pokrovskoye', 'Lebu', 'Hong Kong', 'New Norfolk', 'Bambous Virieux', 'Zemio', 'Mahébourg', 'Castro', 'Sola', 'Saint George', 'Carnarvon', 'Ust-Kuyga', 'Haileybury', 'Pozo Colorado', 'Avarua', 'Shingū'] and id is: [230893, 1015776, 4030556, 3381428, 2137773, 3451138, 1623197, 546105, 3833367, 507427, 3883457, 1819729, 2155415, 1106677, 235826, 934322, 3466704, 2134814, 5546220, 2074865, 2013921, 5968992, 3437443, 4035715, 1847947]
# The city is: ['Kitgum', 'Bredasdorp', 'Rikitea', 'Iracoubo', 'Vao', 'Rio Grande', 'Tual', 'Nikolskoye', 'Ushuaia', 'Pokrovskoye', 'Lebu', 'Hong Kong', 'New Norfolk', 'Bambous Virieux', 'Zemio', 'Mahébourg', 'Castro', 'Sola', 'Saint George', 'Carnarvon', 'Ust-Kuyga', 'Haileybury', 'Pozo Colorado', 'Avarua', 'Shingū', 'Grindavik'] and id is: [230893, 1015776, 4030556, 3381428, 2137773, 3451138, 1623197, 546105, 3833367, 507427, 3883457, 1819729, 2155415, 1106677, 235826, 934322, 3466704, 2134814, 5546220, 2074865, 2013921, 5968992, 3437443, 4035715, 1847947, 3416888]
# The city is: ['Kitgum', 'Bredasdorp', 'Rikitea', 'Iracoubo', 'Vao', 'Rio Grande', 'Tual', 'Nikolskoye', 'Ushuaia', 'Pokrovskoye', 'Lebu', 'Hong Kong', 'New Norfolk', 'Bambous Virieux', 'Zemio', 'Mahébourg', 'Castro', 'Sola', 'Saint George', 'Carnarvon', 'Ust-Kuyga', 'Haileybury', 'Pozo Colorado', 'Avarua', 'Shingū', 'Grindavik', "Severo-Kuril'sk"] and id is: [230893, 1015776, 4030556, 3381428, 2137773, 3451138, 1623197, 546105, 3833367, 507427, 3883457, 1819729, 2155415, 1106677, 235826, 934322, 3466704, 2134814, 5546220, 2074865, 2013921, 5968992, 3437443, 4035715, 1847947, 3416888, 2121385]
# The city is: ['Kitgum', 'Bredasdorp', 'Rikitea', 'Iracoubo', 'Vao', 'Rio Grande', 'Tual', 'Nikolskoye', 'Ushuaia', 'Pokrovskoye', 'Lebu', 'Hong Kong', 'New Norfolk', 'Bambous Virieux', 'Zemio', 'Mahébourg', 'Castro', 'Sola', 'Saint George', 'Carnarvon', 'Ust-Kuyga', 'Haileybury', 'Pozo Colorado', 'Avarua', 'Shingū', 'Grindavik', "Severo-Kuril'sk", 'Lorengau'] and id is: [230893, 1015776, 4030556, 3381428, 2137773, 3451138, 1623197, 546105, 3833367, 507427, 3883457, 1819729, 2155415, 1106677, 235826, 934322, 3466704, 2134814, 5546220, 2074865, 2013921, 5968992, 3437443, 4035715, 1847947, 3416888, 2121385, 2092164]
# The city is: ['Kitgum', 'Bredasdorp', 'Rikitea', 'Iracoubo', 'Vao', 'Rio Grande', 'Tual', 'Nikolskoye', 'Ushuaia', 'Pokrovskoye', 'Lebu', 'Hong Kong', 'New Norfolk', 'Bambous Virieux', 'Zemio', 'Mahébourg', 'Castro', 'Sola', 'Saint George', 'Carnarvon', 'Ust-Kuyga', 'Haileybury', 'Pozo Colorado', 'Avarua', 'Shingū', 'Grindavik', "Severo-Kuril'sk", 'Lorengau', 'Saint-Philippe'] and id is: [230893, 1015776, 4030556, 3381428, 2137773, 3451138, 1623197, 546105, 3833367, 507427, 3883457, 1819729, 2155415, 1106677, 235826, 934322, 3466704, 2134814, 5546220, 2074865, 2013921, 5968992, 3437443, 4035715, 1847947, 3416888, 2121385, 2092164, 935215]
# The city is: ['Kitgum', 'Bredasdorp', 'Rikitea', 'Iracoubo', 'Vao', 'Rio Grande', 'Tual', 'Nikolskoye', 'Ushuaia', 'Pokrovskoye', 'Lebu', 'Hong Kong', 'New Norfolk', 'Bambous Virieux', 'Zemio', 'Mahébourg', 'Castro', 'Sola', 'Saint George', 'Carnarvon', 'Ust-Kuyga', 'Haileybury', 'Pozo Colorado', 'Avarua', 'Shingū', 'Grindavik', "Severo-Kuril'sk", 'Lorengau', 'Saint-Philippe', 'Arraial do Cabo'] and id is: [230893, 1015776, 4030556, 3381428, 2137773, 3451138, 1623197, 546105, 3833367, 507427, 3883457, 1819729, 2155415, 1106677, 235826, 934322, 3466704, 2134814, 5546220, 2074865, 2013921, 5968992, 3437443, 4035715, 1847947, 3416888, 2121385, 2092164, 935215, 3471451]
# The city is: ['Kitgum', 'Bredasdorp', 'Rikitea', 'Iracoubo', 'Vao', 'Rio Grande', 'Tual', 'Nikolskoye', 'Ushuaia', 'Pokrovskoye', 'Lebu', 'Hong Kong', 'New Norfolk', 'Bambous Virieux', 'Zemio', 'Mahébourg', 'Castro', 'Sola', 'Saint George', 'Carnarvon', 'Ust-Kuyga', 'Haileybury', 'Pozo Colorado', 'Avarua', 'Shingū', 'Grindavik', "Severo-Kuril'sk", 'Lorengau', 'Saint-Philippe', 'Arraial do Cabo', 'Leningradskiy'] and id is: [230893, 1015776, 4030556, 3381428, 2137773, 3451138, 1623197, 546105, 3833367, 507427, 3883457, 1819729, 2155415, 1106677, 235826, 934322, 3466704, 2134814, 5546220, 2074865, 2013921, 5968992, 3437443, 4035715, 1847947, 3416888, 2121385, 2092164, 935215, 3471451, 2123814]
# The city is: ['Kitgum', 'Bredasdorp', 'Rikitea', 'Iracoubo', 'Vao', 'Rio Grande', 'Tual', 'Nikolskoye', 'Ushuaia', 'Pokrovskoye', 'Lebu', 'Hong Kong', 'New Norfolk', 'Bambous Virieux', 'Zemio', 'Mahébourg', 'Castro', 'Sola', 'Saint George', 'Carnarvon', 'Ust-Kuyga', 'Haileybury', 'Pozo Colorado', 'Avarua', 'Shingū', 'Grindavik', "Severo-Kuril'sk", 'Lorengau', 'Saint-Philippe', 'Arraial do Cabo', 'Leningradskiy', 'Kavaratti'] and id is: [230893, 1015776, 4030556, 3381428, 2137773, 3451138, 1623197, 546105, 3833367, 507427, 3883457, 1819729, 2155415, 1106677, 235826, 934322, 3466704, 2134814, 5546220, 2074865, 2013921, 5968992, 3437443, 4035715, 1847947, 3416888, 2121385, 2092164, 935215, 3471451, 2123814, 1267390]
# The city is: ['Kitgum', 'Bredasdorp', 'Rikitea', 'Iracoubo', 'Vao', 'Rio Grande', 'Tual', 'Nikolskoye', 'Ushuaia', 'Pokrovskoye', 'Lebu', 'Hong Kong', 'New Norfolk', 'Bambous Virieux', 'Zemio', 'Mahébourg', 'Castro', 'Sola', 'Saint George', 'Carnarvon', 'Ust-Kuyga', 'Haileybury', 'Pozo Colorado', 'Avarua', 'Shingū', 'Grindavik', "Severo-Kuril'sk", 'Lorengau', 'Saint-Philippe', 'Arraial do Cabo', 'Leningradskiy', 'Kavaratti', 'Vila Velha'] and id is: [230893, 1015776, 4030556, 3381428, 2137773, 3451138, 1623197, 546105, 3833367, 507427, 3883457, 1819729, 2155415, 1106677, 235826, 934322, 3466704, 2134814, 5546220, 2074865, 2013921, 5968992, 3437443, 4035715, 1847947, 3416888, 2121385, 2092164, 935215, 3471451, 2123814, 1267390, 3445026]
# The city is: ['Kitgum', 'Bredasdorp', 'Rikitea', 'Iracoubo', 'Vao', 'Rio Grande', 'Tual', 'Nikolskoye', 'Ushuaia', 'Pokrovskoye', 'Lebu', 'Hong Kong', 'New Norfolk', 'Bambous Virieux', 'Zemio', 'Mahébourg', 'Castro', 'Sola', 'Saint George', 'Carnarvon', 'Ust-Kuyga', 'Haileybury', 'Pozo Colorado', 'Avarua', 'Shingū', 'Grindavik', "Severo-Kuril'sk", 'Lorengau', 'Saint-Philippe', 'Arraial do Cabo', 'Leningradskiy', 'Kavaratti', 'Vila Velha', 'Puerto Ayora'] and id is: [230893, 1015776, 4030556, 3381428, 2137773, 3451138, 1623197, 546105, 3833367, 507427, 3883457, 1819729, 2155415, 1106677, 235826, 934322, 3466704, 2134814, 5546220, 2074865, 2013921, 5968992, 3437443, 4035715, 1847947, 3416888, 2121385, 2092164, 935215, 3471451, 2123814, 1267390, 3445026, 3652764]
# No data for that city
# No data for that city
# The city is: ['Kitgum', 'Bredasdorp', 'Rikitea', 'Iracoubo', 'Vao', 'Rio Grande', 'Tual', 'Nikolskoye', 'Ushuaia', 'Pokrovskoye', 'Lebu', 'Hong Kong', 'New Norfolk', 'Bambous Virieux', 'Zemio', 'Mahébourg', 'Castro', 'Sola', 'Saint George', 'Carnarvon', 'Ust-Kuyga', 'Haileybury', 'Pozo Colorado', 'Avarua', 'Shingū', 'Grindavik', "Severo-Kuril'sk", 'Lorengau', 'Saint-Philippe', 'Arraial do Cabo', 'Leningradskiy', 'Kavaratti', 'Vila Velha', 'Puerto Ayora', 'Bengkulu'] and id is: [230893, 1015776, 4030556, 3381428, 2137773, 3451138, 1623197, 546105, 3833367, 507427, 3883457, 1819729, 2155415, 1106677, 235826, 934322, 3466704, 2134814, 5546220, 2074865, 2013921, 5968992, 3437443, 4035715, 1847947, 3416888, 2121385, 2092164, 935215, 3471451, 2123814, 1267390, 3445026, 3652764, 1649150]
# The city is: ['Kitgum', 'Bredasdorp', 'Rikitea', 'Iracoubo', 'Vao', 'Rio Grande', 'Tual', 'Nikolskoye', 'Ushuaia', 'Pokrovskoye', 'Lebu', 'Hong Kong', 'New Norfolk', 'Bambous Virieux', 'Zemio', 'Mahébourg', 'Castro', 'Sola', 'Saint George', 'Carnarvon', 'Ust-Kuyga', 'Haileybury', 'Pozo Colorado', 'Avarua', 'Shingū', 'Grindavik', "Severo-Kuril'sk", 'Lorengau', 'Saint-Philippe', 'Arraial do Cabo', 'Leningradskiy', 'Kavaratti', 'Vila Velha', 'Puerto Ayora', 'Bengkulu', 'Ust-Nera'] and id is: [230893, 1015776, 4030556, 3381428, 2137773, 3451138, 1623197, 546105, 3833367, 507427, 3883457, 1819729, 2155415, 1106677, 235826, 934322, 3466704, 2134814, 5546220, 2074865, 2013921, 5968992, 3437443, 4035715, 1847947, 3416888, 2121385, 2092164, 935215, 3471451, 2123814, 1267390, 3445026, 3652764, 1649150, 2120048]
# The city is: ['Kitgum', 'Bredasdorp', 'Rikitea', 'Iracoubo', 'Vao', 'Rio Grande', 'Tual', 'Nikolskoye', 'Ushuaia', 'Pokrovskoye', 'Lebu', 'Hong Kong', 'New Norfolk', 'Bambous Virieux', 'Zemio', 'Mahébourg', 'Castro', 'Sola', 'Saint George', 'Carnarvon', 'Ust-Kuyga', 'Haileybury', 'Pozo Colorado', 'Avarua', 'Shingū', 'Grindavik', "Severo-Kuril'sk", 'Lorengau', 'Saint-Philippe', 'Arraial do Cabo', 'Leningradskiy', 'Kavaratti', 'Vila Velha', 'Puerto Ayora', 'Bengkulu', 'Ust-Nera', 'Hilo'] and id is: [230893, 1015776, 4030556, 3381428, 2137773, 3451138, 1623197, 546105, 3833367, 507427, 3883457, 1819729, 2155415, 1106677, 235826, 934322, 3466704, 2134814, 5546220, 2074865, 2013921, 5968992, 3437443, 4035715, 1847947, 3416888, 2121385, 2092164, 935215, 3471451, 2123814, 1267390, 3445026, 3652764, 1649150, 2120048, 5855927]
# The city is: ['Kitgum', 'Bredasdorp', 'Rikitea', 'Iracoubo', 'Vao', 'Rio Grande', 'Tual', 'Nikolskoye', 'Ushuaia', 'Pokrovskoye', 'Lebu', 'Hong Kong', 'New Norfolk', 'Bambous Virieux', 'Zemio', 'Mahébourg', 'Castro', 'Sola', 'Saint George', 'Carnarvon', 'Ust-Kuyga', 'Haileybury', 'Pozo Colorado', 'Avarua', 'Shingū', 'Grindavik', "Severo-Kuril'sk", 'Lorengau', 'Saint-Philippe', 'Arraial do Cabo', 'Leningradskiy', 'Kavaratti', 'Vila Velha', 'Puerto Ayora', 'Bengkulu', 'Ust-Nera', 'Hilo', 'Kandrian'] and id is: [230893, 1015776, 4030556, 3381428, 2137773, 3451138, 1623197, 546105, 3833367, 507427, 3883457, 1819729, 2155415, 1106677, 235826, 934322, 3466704, 2134814, 5546220, 2074865, 2013921, 5968992, 3437443, 4035715, 1847947, 3416888, 2121385, 2092164, 935215, 3471451, 2123814, 1267390, 3445026, 3652764, 1649150, 2120048, 5855927, 2094746]
# The city is: ['Kitgum', 'Bredasdorp', 'Rikitea', 'Iracoubo', 'Vao', 'Rio Grande', 'Tual', 'Nikolskoye', 'Ushuaia', 'Pokrovskoye', 'Lebu', 'Hong Kong', 'New Norfolk', 'Bambous Virieux', 'Zemio', 'Mahébourg', 'Castro', 'Sola', 'Saint George', 'Carnarvon', 'Ust-Kuyga', 'Haileybury', 'Pozo Colorado', 'Avarua', 'Shingū', 'Grindavik', "Severo-Kuril'sk", 'Lorengau', 'Saint-Philippe', 'Arraial do Cabo', 'Leningradskiy', 'Kavaratti', 'Vila Velha', 'Puerto Ayora', 'Bengkulu', 'Ust-Nera', 'Hilo', 'Kandrian', 'Clyde River'] and id is: [230893, 1015776, 4030556, 3381428, 2137773, 3451138, 1623197, 546105, 3833367, 507427, 3883457, 1819729, 2155415, 1106677, 235826, 934322, 3466704, 2134814, 5546220, 2074865, 2013921, 5968992, 3437443, 4035715, 1847947, 3416888, 2121385, 2092164, 935215, 3471451, 2123814, 1267390, 3445026, 3652764, 1649150, 2120048, 5855927, 2094746, 5924351]
# The city is: ['Kitgum', 'Bredasdorp', 'Rikitea', 'Iracoubo', 'Vao', 'Rio Grande', 'Tual', 'Nikolskoye', 'Ushuaia', 'Pokrovskoye', 'Lebu', 'Hong Kong', 'New Norfolk', 'Bambous Virieux', 'Zemio', 'Mahébourg', 'Castro', 'Sola', 'Saint George', 'Carnarvon', 'Ust-Kuyga', 'Haileybury', 'Pozo Colorado', 'Avarua', 'Shingū', 'Grindavik', "Severo-Kuril'sk", 'Lorengau', 'Saint-Philippe', 'Arraial do Cabo', 'Leningradskiy', 'Kavaratti', 'Vila Velha', 'Puerto Ayora', 'Bengkulu', 'Ust-Nera', 'Hilo', 'Kandrian', 'Clyde River', 'Hermanus'] and id is: [230893, 1015776, 4030556, 3381428, 2137773, 3451138, 1623197, 546105, 3833367, 507427, 3883457, 1819729, 2155415, 1106677, 235826, 934322, 3466704, 2134814, 5546220, 2074865, 2013921, 5968992, 3437443, 4035715, 1847947, 3416888, 2121385, 2092164, 935215, 3471451, 2123814, 1267390, 3445026, 3652764, 1649150, 2120048, 5855927, 2094746, 5924351, 3366880]
# The city is: ['Kitgum', 'Bredasdorp', 'Rikitea', 'Iracoubo', 'Vao', 'Rio Grande', 'Tual', 'Nikolskoye', 'Ushuaia', 'Pokrovskoye', 'Lebu', 'Hong Kong', 'New Norfolk', 'Bambous Virieux', 'Zemio', 'Mahébourg', 'Castro', 'Sola', 'Saint George', 'Carnarvon', 'Ust-Kuyga', 'Haileybury', 'Pozo Colorado', 'Avarua', 'Shingū', 'Grindavik', "Severo-Kuril'sk", 'Lorengau', 'Saint-Philippe', 'Arraial do Cabo', 'Leningradskiy', 'Kavaratti', 'Vila Velha', 'Puerto Ayora', 'Bengkulu', 'Ust-Nera', 'Hilo', 'Kandrian', 'Clyde River', 'Hermanus', 'Souillac'] and id is: [230893, 1015776, 4030556, 3381428, 2137773, 3451138, 1623197, 546105, 3833367, 507427, 3883457, 1819729, 2155415, 1106677, 235826, 934322, 3466704, 2134814, 5546220, 2074865, 2013921, 5968992, 3437443, 4035715, 1847947, 3416888, 2121385, 2092164, 935215, 3471451, 2123814, 1267390, 3445026, 3652764, 1649150, 2120048, 5855927, 2094746, 5924351, 3366880, 933995]
# The city is: ['Kitgum', 'Bredasdorp', 'Rikitea', 'Iracoubo', 'Vao', 'Rio Grande', 'Tual', 'Nikolskoye', 'Ushuaia', 'Pokrovskoye', 'Lebu', 'Hong Kong', 'New Norfolk', 'Bambous Virieux', 'Zemio', 'Mahébourg', 'Castro', 'Sola', 'Saint George', 'Carnarvon', 'Ust-Kuyga', 'Haileybury', 'Pozo Colorado', 'Avarua', 'Shingū', 'Grindavik', "Severo-Kuril'sk", 'Lorengau', 'Saint-Philippe', 'Arraial do Cabo', 'Leningradskiy', 'Kavaratti', 'Vila Velha', 'Puerto Ayora', 'Bengkulu', 'Ust-Nera', 'Hilo', 'Kandrian', 'Clyde River', 'Hermanus', 'Souillac', 'Baker City'] and id is: [230893, 1015776, 4030556, 3381428, 2137773, 3451138, 1623197, 546105, 3833367, 507427, 3883457, 1819729, 2155415, 1106677, 235826, 934322, 3466704, 2134814, 5546220, 2074865, 2013921, 5968992, 3437443, 4035715, 1847947, 3416888, 2121385, 2092164, 935215, 3471451, 2123814, 1267390, 3445026, 3652764, 1649150, 2120048, 5855927, 2094746, 5924351, 3366880, 933995, 5712169]
# The city is: ['Kitgum', 'Bredasdorp', 'Rikitea', 'Iracoubo', 'Vao', 'Rio Grande', 'Tual', 'Nikolskoye', 'Ushuaia', 'Pokrovskoye', 'Lebu', 'Hong Kong', 'New Norfolk', 'Bambous Virieux', 'Zemio', 'Mahébourg', 'Castro', 'Sola', 'Saint George', 'Carnarvon', 'Ust-Kuyga', 'Haileybury', 'Pozo Colorado', 'Avarua', 'Shingū', 'Grindavik', "Severo-Kuril'sk", 'Lorengau', 'Saint-Philippe', 'Arraial do Cabo', 'Leningradskiy', 'Kavaratti', 'Vila Velha', 'Puerto Ayora', 'Bengkulu', 'Ust-Nera', 'Hilo', 'Kandrian', 'Clyde River', 'Hermanus', 'Souillac', 'Baker City', 'Wahlern'] and id is: [230893, 1015776, 4030556, 3381428, 2137773, 3451138, 1623197, 546105, 3833367, 507427, 3883457, 1819729, 2155415, 1106677, 235826, 934322, 3466704, 2134814, 5546220, 2074865, 2013921, 5968992, 3437443, 4035715, 1847947, 3416888, 2121385, 2092164, 935215, 3471451, 2123814, 1267390, 3445026, 3652764, 1649150, 2120048, 5855927, 2094746, 5924351, 3366880, 933995, 5712169, 2658076]
# The city is: ['Kitgum', 'Bredasdorp', 'Rikitea', 'Iracoubo', 'Vao', 'Rio Grande', 'Tual', 'Nikolskoye', 'Ushuaia', 'Pokrovskoye', 'Lebu', 'Hong Kong', 'New Norfolk', 'Bambous Virieux', 'Zemio', 'Mahébourg', 'Castro', 'Sola', 'Saint George', 'Carnarvon', 'Ust-Kuyga', 'Haileybury', 'Pozo Colorado', 'Avarua', 'Shingū', 'Grindavik', "Severo-Kuril'sk", 'Lorengau', 'Saint-Philippe', 'Arraial do Cabo', 'Leningradskiy', 'Kavaratti', 'Vila Velha', 'Puerto Ayora', 'Bengkulu', 'Ust-Nera', 'Hilo', 'Kandrian', 'Clyde River', 'Hermanus', 'Souillac', 'Baker City', 'Wahlern', 'Longyearbyen'] and id is: [230893, 1015776, 4030556, 3381428, 2137773, 3451138, 1623197, 546105, 3833367, 507427, 3883457, 1819729, 2155415, 1106677, 235826, 934322, 3466704, 2134814, 5546220, 2074865, 2013921, 5968992, 3437443, 4035715, 1847947, 3416888, 2121385, 2092164, 935215, 3471451, 2123814, 1267390, 3445026, 3652764, 1649150, 2120048, 5855927, 2094746, 5924351, 3366880, 933995, 5712169, 2658076, 2729907]
# The city is: ['Kitgum', 'Bredasdorp', 'Rikitea', 'Iracoubo', 'Vao', 'Rio Grande', 'Tual', 'Nikolskoye', 'Ushuaia', 'Pokrovskoye', 'Lebu', 'Hong Kong', 'New Norfolk', 'Bambous Virieux', 'Zemio', 'Mahébourg', 'Castro', 'Sola', 'Saint George', 'Carnarvon', 'Ust-Kuyga', 'Haileybury', 'Pozo Colorado', 'Avarua', 'Shingū', 'Grindavik', "Severo-Kuril'sk", 'Lorengau', 'Saint-Philippe', 'Arraial do Cabo', 'Leningradskiy', 'Kavaratti', 'Vila Velha', 'Puerto Ayora', 'Bengkulu', 'Ust-Nera', 'Hilo', 'Kandrian', 'Clyde River', 'Hermanus', 'Souillac', 'Baker City', 'Wahlern', 'Longyearbyen', 'Punta Arenas'] and id is: [230893, 1015776, 4030556, 3381428, 2137773, 3451138, 1623197, 546105, 3833367, 507427, 3883457, 1819729, 2155415, 1106677, 235826, 934322, 3466704, 2134814, 5546220, 2074865, 2013921, 5968992, 3437443, 4035715, 1847947, 3416888, 2121385, 2092164, 935215, 3471451, 2123814, 1267390, 3445026, 3652764, 1649150, 2120048, 5855927, 2094746, 5924351, 3366880, 933995, 5712169, 2658076, 2729907, 3874787]
# The city is: ['Kitgum', 'Bredasdorp', 'Rikitea', 'Iracoubo', 'Vao', 'Rio Grande', 'Tual', 'Nikolskoye', 'Ushuaia', 'Pokrovskoye', 'Lebu', 'Hong Kong', 'New Norfolk', 'Bambous Virieux', 'Zemio', 'Mahébourg', 'Castro', 'Sola', 'Saint George', 'Carnarvon', 'Ust-Kuyga', 'Haileybury', 'Pozo Colorado', 'Avarua', 'Shingū', 'Grindavik', "Severo-Kuril'sk", 'Lorengau', 'Saint-Philippe', 'Arraial do Cabo', 'Leningradskiy', 'Kavaratti', 'Vila Velha', 'Puerto Ayora', 'Bengkulu', 'Ust-Nera', 'Hilo', 'Kandrian', 'Clyde River', 'Hermanus', 'Souillac', 'Baker City', 'Wahlern', 'Longyearbyen', 'Punta Arenas', 'Alice Springs'] and id is: [230893, 1015776, 4030556, 3381428, 2137773, 3451138, 1623197, 546105, 3833367, 507427, 3883457, 1819729, 2155415, 1106677, 235826, 934322, 3466704, 2134814, 5546220, 2074865, 2013921, 5968992, 3437443, 4035715, 1847947, 3416888, 2121385, 2092164, 935215, 3471451, 2123814, 1267390, 3445026, 3652764, 1649150, 2120048, 5855927, 2094746, 5924351, 3366880, 933995, 5712169, 2658076, 2729907, 3874787, 2077895]
# The city is: ['Kitgum', 'Bredasdorp', 'Rikitea', 'Iracoubo', 'Vao', 'Rio Grande', 'Tual', 'Nikolskoye', 'Ushuaia', 'Pokrovskoye', 'Lebu', 'Hong Kong', 'New Norfolk', 'Bambous Virieux', 'Zemio', 'Mahébourg', 'Castro', 'Sola', 'Saint George', 'Carnarvon', 'Ust-Kuyga', 'Haileybury', 'Pozo Colorado', 'Avarua', 'Shingū', 'Grindavik', "Severo-Kuril'sk", 'Lorengau', 'Saint-Philippe', 'Arraial do Cabo', 'Leningradskiy', 'Kavaratti', 'Vila Velha', 'Puerto Ayora', 'Bengkulu', 'Ust-Nera', 'Hilo', 'Kandrian', 'Clyde River', 'Hermanus', 'Souillac', 'Baker City', 'Wahlern', 'Longyearbyen', 'Punta Arenas', 'Alice Springs', 'Tete'] and id is: [230893, 1015776, 4030556, 3381428, 2137773, 3451138, 1623197, 546105, 3833367, 507427, 3883457, 1819729, 2155415, 1106677, 235826, 934322, 3466704, 2134814, 5546220, 2074865, 2013921, 5968992, 3437443, 4035715, 1847947, 3416888, 2121385, 2092164, 935215, 3471451, 2123814, 1267390, 3445026, 3652764, 1649150, 2120048, 5855927, 2094746, 5924351, 3366880, 933995, 5712169, 2658076, 2729907, 3874787, 2077895, 1026014]
# The city is: ['Kitgum', 'Bredasdorp', 'Rikitea', 'Iracoubo', 'Vao', 'Rio Grande', 'Tual', 'Nikolskoye', 'Ushuaia', 'Pokrovskoye', 'Lebu', 'Hong Kong', 'New Norfolk', 'Bambous Virieux', 'Zemio', 'Mahébourg', 'Castro', 'Sola', 'Saint George', 'Carnarvon', 'Ust-Kuyga', 'Haileybury', 'Pozo Colorado', 'Avarua', 'Shingū', 'Grindavik', "Severo-Kuril'sk", 'Lorengau', 'Saint-Philippe', 'Arraial do Cabo', 'Leningradskiy', 'Kavaratti', 'Vila Velha', 'Puerto Ayora', 'Bengkulu', 'Ust-Nera', 'Hilo', 'Kandrian', 'Clyde River', 'Hermanus', 'Souillac', 'Baker City', 'Wahlern', 'Longyearbyen', 'Punta Arenas', 'Alice Springs', 'Tete', 'Rawson'] and id is: [230893, 1015776, 4030556, 3381428, 2137773, 3451138, 1623197, 546105, 3833367, 507427, 3883457, 1819729, 2155415, 1106677, 235826, 934322, 3466704, 2134814, 5546220, 2074865, 2013921, 5968992, 3437443, 4035715, 1847947, 3416888, 2121385, 2092164, 935215, 3471451, 2123814, 1267390, 3445026, 3652764, 1649150, 2120048, 5855927, 2094746, 5924351, 3366880, 933995, 5712169, 2658076, 2729907, 3874787, 2077895, 1026014, 3839307]
# The city is: ['Kitgum', 'Bredasdorp', 'Rikitea', 'Iracoubo', 'Vao', 'Rio Grande', 'Tual', 'Nikolskoye', 'Ushuaia', 'Pokrovskoye', 'Lebu', 'Hong Kong', 'New Norfolk', 'Bambous Virieux', 'Zemio', 'Mahébourg', 'Castro', 'Sola', 'Saint George', 'Carnarvon', 'Ust-Kuyga', 'Haileybury', 'Pozo Colorado', 'Avarua', 'Shingū', 'Grindavik', "Severo-Kuril'sk", 'Lorengau', 'Saint-Philippe', 'Arraial do Cabo', 'Leningradskiy', 'Kavaratti', 'Vila Velha', 'Puerto Ayora', 'Bengkulu', 'Ust-Nera', 'Hilo', 'Kandrian', 'Clyde River', 'Hermanus', 'Souillac', 'Baker City', 'Wahlern', 'Longyearbyen', 'Punta Arenas', 'Alice Springs', 'Tete', 'Rawson', 'Initao'] and id is: [230893, 1015776, 4030556, 3381428, 2137773, 3451138, 1623197, 546105, 3833367, 507427, 3883457, 1819729, 2155415, 1106677, 235826, 934322, 3466704, 2134814, 5546220, 2074865, 2013921, 5968992, 3437443, 4035715, 1847947, 3416888, 2121385, 2092164, 935215, 3471451, 2123814, 1267390, 3445026, 3652764, 1649150, 2120048, 5855927, 2094746, 5924351, 3366880, 933995, 5712169, 2658076, 2729907, 3874787, 2077895, 1026014, 3839307, 1710705]
# The city is: ['Kitgum', 'Bredasdorp', 'Rikitea', 'Iracoubo', 'Vao', 'Rio Grande', 'Tual', 'Nikolskoye', 'Ushuaia', 'Pokrovskoye', 'Lebu', 'Hong Kong', 'New Norfolk', 'Bambous Virieux', 'Zemio', 'Mahébourg', 'Castro', 'Sola', 'Saint George', 'Carnarvon', 'Ust-Kuyga', 'Haileybury', 'Pozo Colorado', 'Avarua', 'Shingū', 'Grindavik', "Severo-Kuril'sk", 'Lorengau', 'Saint-Philippe', 'Arraial do Cabo', 'Leningradskiy', 'Kavaratti', 'Vila Velha', 'Puerto Ayora', 'Bengkulu', 'Ust-Nera', 'Hilo', 'Kandrian', 'Clyde River', 'Hermanus', 'Souillac', 'Baker City', 'Wahlern', 'Longyearbyen', 'Punta Arenas', 'Alice Springs', 'Tete', 'Rawson', 'Initao', 'Monterrey'] and id is: [230893, 1015776, 4030556, 3381428, 2137773, 3451138, 1623197, 546105, 3833367, 507427, 3883457, 1819729, 2155415, 1106677, 235826, 934322, 3466704, 2134814, 5546220, 2074865, 2013921, 5968992, 3437443, 4035715, 1847947, 3416888, 2121385, 2092164, 935215, 3471451, 2123814, 1267390, 3445026, 3652764, 1649150, 2120048, 5855927, 2094746, 5924351, 3366880, 933995, 5712169, 2658076, 2729907, 3874787, 2077895, 1026014, 3839307, 1710705, 3995465]
# The city is: ['Kitgum', 'Bredasdorp', 'Rikitea', 'Iracoubo', 'Vao', 'Rio Grande', 'Tual', 'Nikolskoye', 'Ushuaia', 'Pokrovskoye', 'Lebu', 'Hong Kong', 'New Norfolk', 'Bambous Virieux', 'Zemio', 'Mahébourg', 'Castro', 'Sola', 'Saint George', 'Carnarvon', 'Ust-Kuyga', 'Haileybury', 'Pozo Colorado', 'Avarua', 'Shingū', 'Grindavik', "Severo-Kuril'sk", 'Lorengau', 'Saint-Philippe', 'Arraial do Cabo', 'Leningradskiy', 'Kavaratti', 'Vila Velha', 'Puerto Ayora', 'Bengkulu', 'Ust-Nera', 'Hilo', 'Kandrian', 'Clyde River', 'Hermanus', 'Souillac', 'Baker City', 'Wahlern', 'Longyearbyen', 'Punta Arenas', 'Alice Springs', 'Tete', 'Rawson', 'Initao', 'Monterrey', 'Petropavlovsk-Kamchatskiy'] and id is: [230893, 1015776, 4030556, 3381428, 2137773, 3451138, 1623197, 546105, 3833367, 507427, 3883457, 1819729, 2155415, 1106677, 235826, 934322, 3466704, 2134814, 5546220, 2074865, 2013921, 5968992, 3437443, 4035715, 1847947, 3416888, 2121385, 2092164, 935215, 3471451, 2123814, 1267390, 3445026, 3652764, 1649150, 2120048, 5855927, 2094746, 5924351, 3366880, 933995, 5712169, 2658076, 2729907, 3874787, 2077895, 1026014, 3839307, 1710705, 3995465, 2122104]
# The city is: ['Kitgum', 'Bredasdorp', 'Rikitea', 'Iracoubo', 'Vao', 'Rio Grande', 'Tual', 'Nikolskoye', 'Ushuaia', 'Pokrovskoye', 'Lebu', 'Hong Kong', 'New Norfolk', 'Bambous Virieux', 'Zemio', 'Mahébourg', 'Castro', 'Sola', 'Saint George', 'Carnarvon', 'Ust-Kuyga', 'Haileybury', 'Pozo Colorado', 'Avarua', 'Shingū', 'Grindavik', "Severo-Kuril'sk", 'Lorengau', 'Saint-Philippe', 'Arraial do Cabo', 'Leningradskiy', 'Kavaratti', 'Vila Velha', 'Puerto Ayora', 'Bengkulu', 'Ust-Nera', 'Hilo', 'Kandrian', 'Clyde River', 'Hermanus', 'Souillac', 'Baker City', 'Wahlern', 'Longyearbyen', 'Punta Arenas', 'Alice Springs', 'Tete', 'Rawson', 'Initao', 'Monterrey', 'Petropavlovsk-Kamchatskiy', 'Omboué'] and id is: [230893, 1015776, 4030556, 3381428, 2137773, 3451138, 1623197, 546105, 3833367, 507427, 3883457, 1819729, 2155415, 1106677, 235826, 934322, 3466704, 2134814, 5546220, 2074865, 2013921, 5968992, 3437443, 4035715, 1847947, 3416888, 2121385, 2092164, 935215, 3471451, 2123814, 1267390, 3445026, 3652764, 1649150, 2120048, 5855927, 2094746, 5924351, 3366880, 933995, 5712169, 2658076, 2729907, 3874787, 2077895, 1026014, 3839307, 1710705, 3995465, 2122104, 2396853]
# The city is: ['Kitgum', 'Bredasdorp', 'Rikitea', 'Iracoubo', 'Vao', 'Rio Grande', 'Tual', 'Nikolskoye', 'Ushuaia', 'Pokrovskoye', 'Lebu', 'Hong Kong', 'New Norfolk', 'Bambous Virieux', 'Zemio', 'Mahébourg', 'Castro', 'Sola', 'Saint George', 'Carnarvon', 'Ust-Kuyga', 'Haileybury', 'Pozo Colorado', 'Avarua', 'Shingū', 'Grindavik', "Severo-Kuril'sk", 'Lorengau', 'Saint-Philippe', 'Arraial do Cabo', 'Leningradskiy', 'Kavaratti', 'Vila Velha', 'Puerto Ayora', 'Bengkulu', 'Ust-Nera', 'Hilo', 'Kandrian', 'Clyde River', 'Hermanus', 'Souillac', 'Baker City', 'Wahlern', 'Longyearbyen', 'Punta Arenas', 'Alice Springs', 'Tete', 'Rawson', 'Initao', 'Monterrey', 'Petropavlovsk-Kamchatskiy', 'Omboué', 'Ryōtsu-minato'] and id is: [230893, 1015776, 4030556, 3381428, 2137773, 3451138, 1623197, 546105, 3833367, 507427, 3883457, 1819729, 2155415, 1106677, 235826, 934322, 3466704, 2134814, 5546220, 2074865, 2013921, 5968992, 3437443, 4035715, 1847947, 3416888, 2121385, 2092164, 935215, 3471451, 2123814, 1267390, 3445026, 3652764, 1649150, 2120048, 5855927, 2094746, 5924351, 3366880, 933995, 5712169, 2658076, 2729907, 3874787, 2077895, 1026014, 3839307, 1710705, 3995465, 2122104, 2396853, 1853371]
# The city is: ['Kitgum', 'Bredasdorp', 'Rikitea', 'Iracoubo', 'Vao', 'Rio Grande', 'Tual', 'Nikolskoye', 'Ushuaia', 'Pokrovskoye', 'Lebu', 'Hong Kong', 'New Norfolk', 'Bambous Virieux', 'Zemio', 'Mahébourg', 'Castro', 'Sola', 'Saint George', 'Carnarvon', 'Ust-Kuyga', 'Haileybury', 'Pozo Colorado', 'Avarua', 'Shingū', 'Grindavik', "Severo-Kuril'sk", 'Lorengau', 'Saint-Philippe', 'Arraial do Cabo', 'Leningradskiy', 'Kavaratti', 'Vila Velha', 'Puerto Ayora', 'Bengkulu', 'Ust-Nera', 'Hilo', 'Kandrian', 'Clyde River', 'Hermanus', 'Souillac', 'Baker City', 'Wahlern', 'Longyearbyen', 'Punta Arenas', 'Alice Springs', 'Tete', 'Rawson', 'Initao', 'Monterrey', 'Petropavlovsk-Kamchatskiy', 'Omboué', 'Ryōtsu-minato', 'Cap Malheureux'] and id is: [230893, 1015776, 4030556, 3381428, 2137773, 3451138, 1623197, 546105, 3833367, 507427, 3883457, 1819729, 2155415, 1106677, 235826, 934322, 3466704, 2134814, 5546220, 2074865, 2013921, 5968992, 3437443, 4035715, 1847947, 3416888, 2121385, 2092164, 935215, 3471451, 2123814, 1267390, 3445026, 3652764, 1649150, 2120048, 5855927, 2094746, 5924351, 3366880, 933995, 5712169, 2658076, 2729907, 3874787, 2077895, 1026014, 3839307, 1710705, 3995465, 2122104, 2396853, 1853371, 934649]
# The city is: ['Kitgum', 'Bredasdorp', 'Rikitea', 'Iracoubo', 'Vao', 'Rio Grande', 'Tual', 'Nikolskoye', 'Ushuaia', 'Pokrovskoye', 'Lebu', 'Hong Kong', 'New Norfolk', 'Bambous Virieux', 'Zemio', 'Mahébourg', 'Castro', 'Sola', 'Saint George', 'Carnarvon', 'Ust-Kuyga', 'Haileybury', 'Pozo Colorado', 'Avarua', 'Shingū', 'Grindavik', "Severo-Kuril'sk", 'Lorengau', 'Saint-Philippe', 'Arraial do Cabo', 'Leningradskiy', 'Kavaratti', 'Vila Velha', 'Puerto Ayora', 'Bengkulu', 'Ust-Nera', 'Hilo', 'Kandrian', 'Clyde River', 'Hermanus', 'Souillac', 'Baker City', 'Wahlern', 'Longyearbyen', 'Punta Arenas', 'Alice Springs', 'Tete', 'Rawson', 'Initao', 'Monterrey', 'Petropavlovsk-Kamchatskiy', 'Omboué', 'Ryōtsu-minato', 'Cap Malheureux', 'Olafsvik'] and id is: [230893, 1015776, 4030556, 3381428, 2137773, 3451138, 1623197, 546105, 3833367, 507427, 3883457, 1819729, 2155415, 1106677, 235826, 934322, 3466704, 2134814, 5546220, 2074865, 2013921, 5968992, 3437443, 4035715, 1847947, 3416888, 2121385, 2092164, 935215, 3471451, 2123814, 1267390, 3445026, 3652764, 1649150, 2120048, 5855927, 2094746, 5924351, 3366880, 933995, 5712169, 2658076, 2729907, 3874787, 2077895, 1026014, 3839307, 1710705, 3995465, 2122104, 2396853, 1853371, 934649, 3414079]
# The city is: ['Kitgum', 'Bredasdorp', 'Rikitea', 'Iracoubo', 'Vao', 'Rio Grande', 'Tual', 'Nikolskoye', 'Ushuaia', 'Pokrovskoye', 'Lebu', 'Hong Kong', 'New Norfolk', 'Bambous Virieux', 'Zemio', 'Mahébourg', 'Castro', 'Sola', 'Saint George', 'Carnarvon', 'Ust-Kuyga', 'Haileybury', 'Pozo Colorado', 'Avarua', 'Shingū', 'Grindavik', "Severo-Kuril'sk", 'Lorengau', 'Saint-Philippe', 'Arraial do Cabo', 'Leningradskiy', 'Kavaratti', 'Vila Velha', 'Puerto Ayora', 'Bengkulu', 'Ust-Nera', 'Hilo', 'Kandrian', 'Clyde River', 'Hermanus', 'Souillac', 'Baker City', 'Wahlern', 'Longyearbyen', 'Punta Arenas', 'Alice Springs', 'Tete', 'Rawson', 'Initao', 'Monterrey', 'Petropavlovsk-Kamchatskiy', 'Omboué', 'Ryōtsu-minato', 'Cap Malheureux', 'Olafsvik', 'Port Alfred'] and id is: [230893, 1015776, 4030556, 3381428, 2137773, 3451138, 1623197, 546105, 3833367, 507427, 3883457, 1819729, 2155415, 1106677, 235826, 934322, 3466704, 2134814, 5546220, 2074865, 2013921, 5968992, 3437443, 4035715, 1847947, 3416888, 2121385, 2092164, 935215, 3471451, 2123814, 1267390, 3445026, 3652764, 1649150, 2120048, 5855927, 2094746, 5924351, 3366880, 933995, 5712169, 2658076, 2729907, 3874787, 2077895, 1026014, 3839307, 1710705, 3995465, 2122104, 2396853, 1853371, 934649, 3414079, 964432]
# The city is: ['Kitgum', 'Bredasdorp', 'Rikitea', 'Iracoubo', 'Vao', 'Rio Grande', 'Tual', 'Nikolskoye', 'Ushuaia', 'Pokrovskoye', 'Lebu', 'Hong Kong', 'New Norfolk', 'Bambous Virieux', 'Zemio', 'Mahébourg', 'Castro', 'Sola', 'Saint George', 'Carnarvon', 'Ust-Kuyga', 'Haileybury', 'Pozo Colorado', 'Avarua', 'Shingū', 'Grindavik', "Severo-Kuril'sk", 'Lorengau', 'Saint-Philippe', 'Arraial do Cabo', 'Leningradskiy', 'Kavaratti', 'Vila Velha', 'Puerto Ayora', 'Bengkulu', 'Ust-Nera', 'Hilo', 'Kandrian', 'Clyde River', 'Hermanus', 'Souillac', 'Baker City', 'Wahlern', 'Longyearbyen', 'Punta Arenas', 'Alice Springs', 'Tete', 'Rawson', 'Initao', 'Monterrey', 'Petropavlovsk-Kamchatskiy', 'Omboué', 'Ryōtsu-minato', 'Cap Malheureux', 'Olafsvik', 'Port Alfred', 'Ribeira Grande'] and id is: [230893, 1015776, 4030556, 3381428, 2137773, 3451138, 1623197, 546105, 3833367, 507427, 3883457, 1819729, 2155415, 1106677, 235826, 934322, 3466704, 2134814, 5546220, 2074865, 2013921, 5968992, 3437443, 4035715, 1847947, 3416888, 2121385, 2092164, 935215, 3471451, 2123814, 1267390, 3445026, 3652764, 1649150, 2120048, 5855927, 2094746, 5924351, 3366880, 933995, 5712169, 2658076, 2729907, 3874787, 2077895, 1026014, 3839307, 1710705, 3995465, 2122104, 2396853, 1853371, 934649, 3414079, 964432, 3372707]
# The city is: ['Kitgum', 'Bredasdorp', 'Rikitea', 'Iracoubo', 'Vao', 'Rio Grande', 'Tual', 'Nikolskoye', 'Ushuaia', 'Pokrovskoye', 'Lebu', 'Hong Kong', 'New Norfolk', 'Bambous Virieux', 'Zemio', 'Mahébourg', 'Castro', 'Sola', 'Saint George', 'Carnarvon', 'Ust-Kuyga', 'Haileybury', 'Pozo Colorado', 'Avarua', 'Shingū', 'Grindavik', "Severo-Kuril'sk", 'Lorengau', 'Saint-Philippe', 'Arraial do Cabo', 'Leningradskiy', 'Kavaratti', 'Vila Velha', 'Puerto Ayora', 'Bengkulu', 'Ust-Nera', 'Hilo', 'Kandrian', 'Clyde River', 'Hermanus', 'Souillac', 'Baker City', 'Wahlern', 'Longyearbyen', 'Punta Arenas', 'Alice Springs', 'Tete', 'Rawson', 'Initao', 'Monterrey', 'Petropavlovsk-Kamchatskiy', 'Omboué', 'Ryōtsu-minato', 'Cap Malheureux', 'Olafsvik', 'Port Alfred', 'Ribeira Grande', 'Poum'] and id is: [230893, 1015776, 4030556, 3381428, 2137773, 3451138, 1623197, 546105, 3833367, 507427, 3883457, 1819729, 2155415, 1106677, 235826, 934322, 3466704, 2134814, 5546220, 2074865, 2013921, 5968992, 3437443, 4035715, 1847947, 3416888, 2121385, 2092164, 935215, 3471451, 2123814, 1267390, 3445026, 3652764, 1649150, 2120048, 5855927, 2094746, 5924351, 3366880, 933995, 5712169, 2658076, 2729907, 3874787, 2077895, 1026014, 3839307, 1710705, 3995465, 2122104, 2396853, 1853371, 934649, 3414079, 964432, 3372707, 2138555]
# The city is: ['Kitgum', 'Bredasdorp', 'Rikitea', 'Iracoubo', 'Vao', 'Rio Grande', 'Tual', 'Nikolskoye', 'Ushuaia', 'Pokrovskoye', 'Lebu', 'Hong Kong', 'New Norfolk', 'Bambous Virieux', 'Zemio', 'Mahébourg', 'Castro', 'Sola', 'Saint George', 'Carnarvon', 'Ust-Kuyga', 'Haileybury', 'Pozo Colorado', 'Avarua', 'Shingū', 'Grindavik', "Severo-Kuril'sk", 'Lorengau', 'Saint-Philippe', 'Arraial do Cabo', 'Leningradskiy', 'Kavaratti', 'Vila Velha', 'Puerto Ayora', 'Bengkulu', 'Ust-Nera', 'Hilo', 'Kandrian', 'Clyde River', 'Hermanus', 'Souillac', 'Baker City', 'Wahlern', 'Longyearbyen', 'Punta Arenas', 'Alice Springs', 'Tete', 'Rawson', 'Initao', 'Monterrey', 'Petropavlovsk-Kamchatskiy', 'Omboué', 'Ryōtsu-minato', 'Cap Malheureux', 'Olafsvik', 'Port Alfred', 'Ribeira Grande', 'Poum', 'Ulladulla'] and id is: [230893, 1015776, 4030556, 3381428, 2137773, 3451138, 1623197, 546105, 3833367, 507427, 3883457, 1819729, 2155415, 1106677, 235826, 934322, 3466704, 2134814, 5546220, 2074865, 2013921, 5968992, 3437443, 4035715, 1847947, 3416888, 2121385, 2092164, 935215, 3471451, 2123814, 1267390, 3445026, 3652764, 1649150, 2120048, 5855927, 2094746, 5924351, 3366880, 933995, 5712169, 2658076, 2729907, 3874787, 2077895, 1026014, 3839307, 1710705, 3995465, 2122104, 2396853, 1853371, 934649, 3414079, 964432, 3372707, 2138
dongsheng', 'Mandalgovi', 'Oudtshoorn', 'Ciudad Bolivar', 'Miles City', 'The Valley', 'Kununurra', 'Chunskiy', 'La Ronge', 'Borazjan', 'Praia', 'Nago', 'Namatanai', 'Novy Urengoy', 'Altay', 'Vaini', 'Tilichiki', 'Santa Marinella', 'Tongren', 'Mar del Plata', 'Ahipara', 'Koulikoro', 'Lagos', 'Syracuse', 'Kruisfontein', 'Donskoye', 'Kuusamo', 'Lompoc', 'Eyl', 'Mugur-Aksy', 'Røros', 'Mossamedes', 'Charters Towers', 'Port Elizabeth', 'Basco', 'Coyhaique', 'Līsakovsk', 'Chapais', 'Marystown', 'Knysna', 'Fortuna', 'Cherskiy', 'Chokurdakh', 'Shimoda', 'Nantucket', 'Nome', 'Qaanaaq', 'Cukai', 'Pampas', 'Pimenta Bueno', 'Takoradze', 'Aklavik', 'Khandagayty', 'Albany', 'Wilmington', 'Dali', 'Piteå', 'North Bend', 'Chernyshevskiy', 'Punta Cardon', 'San Policarpo', 'Kirakira', 'Yumen', 'Laguna', 'Necochea', 'Jurm', 'Vanimo', 'Dabeiba', 'Egvekinot', 'Beringovskiy', 'Balkanabat', 'Qaqortoq', 'Fayaoué', 'Bathsheba', 'Magnolia', 'Caxito', 'Novogagatli', 'Chitipa', 'Norman Wells', 'Villacarrillo', 'Tall Kayf', 'Vaitape', 'Saldanha', 'Tifton', 'Pointe Michel', 'Pangnirtung', 'Harper', 'West Fargo', 'Ponta do Sol', 'Kerman', 'Jatai', 'Havre-St-Pierre', 'Bandarbeyla', 'Valparaíso', 'Bahía Blanca', 'Isangel', 'George Town', 'Paraná', 'Champerico', 'Khatanga', 'Tasiilaq', 'Morón', 'Alofi', 'Dunedin', 'Kumul', 'Iskateley', 'Savalou', 'Hammerfest', 'Ereymentau', 'Birobidzhan', 'Cururupu', 'Sherlovaya Gora', 'Nouakchott', 'Baykit', 'Yachimata', 'Paita', 'Flin Flon', 'Sisimiut', 'Andenes', 'Puerto Escondido', 'Lagoa', 'Bargteheide', 'Talnakh', 'Sabang', 'Klaksvík', 'Mackenzie', 'Adré', 'Tiksi', 'Daphne', 'Paiján', 'Ati', 'Alexandria', 'Otane', 'Torbay', 'Bethel', 'Qasigiannguit', 'Meulaboh', 'Avera', 'Padang', 'Hamilton', 'Shache', 'Gijang', 'Ilulissat', 'Talara', 'San Bartolomé de Tirajana', 'Vilcún', 'Gombong', 'Minsk', 'Pacific Grove', 'Santoña', 'Kamenka', 'Kolosovka', 'Kushchëvskaya', 'Nagato', 'Mergen', 'Tlachichuca', 'Iranshahr', 'Iquique', 'Linköping', 'Malé', 'Narasannapeta', 'Griffith', 'Yellowknife', 'Rome', 'Igarka', 'Haines Junction', 'Tabuk', 'Itarema', 'Darnah', 'Kyra', 'Saint-Joseph', 'Key West', "Ust'-Uda", 'Pontes e Lacerda', 'Kinel’-Cherkassy', 'Iqaluit', 'L ...

# %%
len(cityname)
# Out:
# 551

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# create a data frame from cities, latitude, longitude, max temp, humidity, cloudiness, wind speed, country and date
weather_dict = {
    "City": cityname,
    "Lat": lat,
    "Lng": lon,
    "Max Temp":max_temp,
    "Humidity":humidity,
    "Cloudiness":cloudiness,
    "Wind Speed":windspeed,
    "Country":country,
    "Date":date
}
weather_data = pd.DataFrame(weather_dict)
weather_data
# Out:
#            City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0        Kitgum   3.28   32.89     18.34        91          35        1.63
# 1    Bredasdorp -34.53   20.04      9.00        93           0        2.10
# 2       Rikitea -23.12 -134.97     23.29        77          11        3.64
# 3      Iracoubo   5.48  -53.20     26.68        84          90        3.18
# 4           Vao -22.67  167.48     19.04        69          32        7.60
# ..          ...    ...     ...       ...       ...         ...         ...
# 546       Dubai  25.26   55.30     36.00        53          38        2.60
# 547         Sur  22.57   59.53     28.79        72          12        5.20
# 548        Lata  40.16   -8.33     19.44        72           0        2.68
# 549     Okhotsk  59.38  143.30     16.23        61           0        1.93
# 550    Bilibino  68.05  166.44      8.65        78         100        1.12
#
#     Country        Date
# 0        UG  1596317805
# 1        ZA  1596317806
# 2        PF  1596317668
# 3        GF  1596317669
# 4        NC  1596317669
# ..      ...         ...
# 546      AE  1596317731
# 547      OM  1596317805
# 548      PT  1596317614
# 549      RU  1596317805
# 550      RU  1596317805
#
# [551 rows x 9 columns]

# %%
weather_data.max()
# Out:
# City               Şabyā
# Lat                78.22
# Lng               179.32
# Max Temp           42.78
# Humidity             100
# Cloudiness           100
# Wind Speed         13.19
# Country               ZM
# Date          1596317890
# dtype: object

# %%
weather_data.describe()
# Out:
#               Lat         Lng    Max Temp    Humidity  Cloudiness  Wind Speed  \
# count  551.000000  551.000000  551.000000  551.000000  551.000000  551.000000
# mean    19.811325   20.082740   20.696316   71.499093   46.698730    3.503067
# std     33.605991   90.468698    7.642045   19.952933   39.089454    2.320556
# min    -54.800000 -179.170000    1.000000    8.000000    0.000000    0.120000
# 25%     -8.260000  -59.430000   14.515000   61.500000    2.000000    1.790000
# 50%     22.680000   23.030000   21.890000   77.000000   40.000000    3.100000
# 75%     47.560000  100.345000   26.500000   86.000000   90.000000    4.600000
# max     78.220000  179.320000   42.780000  100.000000  100.000000   13.190000
#
#                Date
# count  5.510000e+02
# mean   1.596318e+09
# std    8.696476e+01
# min    1.596317e+09
# 25%    1.596318e+09
# 50%    1.596318e+09
# 75%    1.596318e+09
# max    1.596318e+09

# %%
# No cities with over 100% humidity

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

# %%
# Extract relevant fields from the data frame

clean_city_data = pd.DataFrame(weather_data)
clean_city_data
# Export the City_Data into a csv
# Out:
#            City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0        Kitgum   3.28   32.89     18.34        91          35        1.63
# 1    Bredasdorp -34.53   20.04      9.00        93           0        2.10
# 2       Rikitea -23.12 -134.97     23.29        77          11        3.64
# 3      Iracoubo   5.48  -53.20     26.68        84          90        3.18
# 4           Vao -22.67  167.48     19.04        69          32        7.60
# ..          ...    ...     ...       ...       ...         ...         ...
# 546       Dubai  25.26   55.30     36.00        53          38        2.60
# 547         Sur  22.57   59.53     28.79        72          12        5.20
# 548        Lata  40.16   -8.33     19.44        72           0        2.68
# 549     Okhotsk  59.38  143.30     16.23        61           0        1.93
# 550    Bilibino  68.05  166.44      8.65        78         100        1.12
#
#     Country        Date
# 0        UG  1596317805
# 1        ZA  1596317806
# 2        PF  1596317668
# 3        GF  1596317669
# 4        NC  1596317669
# ..      ...         ...
# 546      AE  1596317731
# 547      OM  1596317805
# 548      PT  1596317614
# 549      RU  1596317805
# 550      RU  1596317805
#
# [551 rows x 9 columns]

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
# Create a Scatter Plot for temperature vs latitude
plt.figure(figsize=(9,5))
x_values = clean_city_data["Lat"]
y_values = clean_city_data["Max Temp"]
plt.scatter(x_values,y_values)
plt.title("City Latitude vs Max Temperature (08/01/2020)", fontdict={"fontweight":"bold", "fontsize": 14})
plt.xlabel("Latitude", fontdict={"fontsize": 12})
plt.ylabel("Maximum Temperature (C)", fontdict={"fontsize": 12})
plt.savefig("Latitude v Temp.png", dpi=200)
plt.show()
#plt.scatter(weights, tumors, marker="+", color="b") try to change edge color? and add grid

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
# Create a Scatter Plot for temperature vs latitude
plt.figure(figsize=(9,5))
x_values = clean_city_data["Lat"]
y_values = clean_city_data["Humidity"]
plt.scatter(x_values,y_values)
plt.title("City Latitude vs Humidity (08/01/2020)", fontdict={"fontweight":"bold", "fontsize": 14})
plt.xlabel("Latitude", fontdict={"fontsize": 12})
plt.ylabel("Humidity (%)", fontdict={"fontsize": 12})
plt.savefig("Latitude v Humidity.png", dpi=200)
plt.show()

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
# Create a Scatter Plot for cloudiness vs latitude
plt.figure(figsize=(9,5))
x_values = clean_city_data["Lat"]
y_values = clean_city_data["Cloudiness"]
plt.scatter(x_values,y_values)
plt.title("City Latitude vs Cloudiness (08/01/2020)", fontdict={"fontweight":"bold", "fontsize": 14})
plt.xlabel("Latitude", fontdict={"fontsize": 12})
plt.ylabel("Cloudiness (%)", fontdict={"fontsize": 12})
plt.savefig("Latitude v Cloudiness.png", dpi=200)
plt.show()

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
# Create a Scatter Plot for wind speed vs latitude
plt.figure(figsize=(9,5))
x_values = clean_city_data["Lat"]
y_values = clean_city_data["Wind Speed"]
plt.scatter(x_values,y_values)
plt.title("City Latitude vs Wind Speed (08/01/2020)", fontdict={"fontweight":"bold", "fontsize": 14})
plt.xlabel("Latitude", fontdict={"fontsize": 12})
plt.ylabel("Wind Speed (m/s)", fontdict={"fontsize": 12})
plt.savefig("Latitude v Wind Speed.png", dpi=200)
plt.show()

# %% [markdown]
# ## Linear Regression

# %%
# OPTIONAL: Create a function to create Linear Regression plots

# %%
# Create Northern Hemisphere Dataframe
northernhem_lat = clean_city_data.loc[clean_city_data["Lat"] > 0]
northernhem_lat
# Out:
#             City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0         Kitgum   3.28   32.89     18.34        91          35        1.63
# 3       Iracoubo   5.48  -53.20     26.68        84          90        3.18
# 7     Nikolskoye  59.70   30.79     12.78        81          40        1.00
# 9    Pokrovskoye  47.42   38.90     18.33        68          26        1.79
# 11     Hong Kong  22.29  114.16     26.67        88         100        4.92
# ..           ...    ...     ...       ...       ...         ...         ...
# 546        Dubai  25.26   55.30     36.00        53          38        2.60
# 547          Sur  22.57   59.53     28.79        72          12        5.20
# 548         Lata  40.16   -8.33     19.44        72           0        2.68
# 549      Okhotsk  59.38  143.30     16.23        61           0        1.93
# 550     Bilibino  68.05  166.44      8.65        78         100        1.12
#
#     Country        Date
# 0        UG  1596317805
# 3        GF  1596317669
# 7        RU  1596317587
# 9        RU  1596317807
# 11       HK  1596317795
# ..      ...         ...
# 546      AE  1596317731
# 547      OM  1596317805
# 548      PT  1596317614
# 549      RU  1596317805
# 550      RU  1596317805
#
# [375 rows x 9 columns]

# %%
# Create Southern Hemisphere Dataframe
southernhem_lat = clean_city_data.loc[clean_city_data["Lat"] < 0]
southernhem_lat
# Out:
#                City    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 1        Bredasdorp -34.53   20.04      9.00        93           0
# 2           Rikitea -23.12 -134.97     23.29        77          11
# 4               Vao -22.67  167.48     19.04        69          32
# 5        Rio Grande -32.03  -52.10     18.00        72           0
# 6              Tual  -5.67  132.75     25.21        80          97
# ..              ...    ...     ...       ...       ...         ...
# 526           Metro  -5.11  105.31     21.06        87          65
# 528      Trenggalek  -8.05  111.72     22.05        87          83
# 530         Jayanca  -6.39  -79.82     26.67        55           0
# 533    Quatre Cocos -20.21   57.76     22.00        83          75
# 543  Port Macquarie -31.43  152.92      8.89        98           1
#
#      Wind Speed Country        Date
# 1          2.10      ZA  1596317806
# 2          3.64      PF  1596317668
# 4          7.60      NC  1596317669
# 5          4.10      BR  1596317669
# 6          9.02      ID  1596317669
# ..          ...     ...         ...
# 526        1.64      ID  1596317799
# 528        1.93      ID  1596317800
# 530        2.24      PE  1596317801
# 533        7.70      MU  1596317801
# 543        1.64      AU  1596317804
#
# [176 rows x 9 columns]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Create x and y values for Northern Hemisphere Temp and Latitude
x_values = northernhem_lat["Lat"]
y_values = northernhem_lat["Max Temp"]

# Perform a linear regression on max temperature vs. latitude
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

# Get regression values
regress_values = x_values * slope + intercept

# Create line equation string
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))

# %%
# Create Plot
plt.figure(figsize=(9,5))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")

# Label plot and annotate the line equation
plt.xlabel("Latitude", fontdict={"fontsize": 12})
plt.ylabel("Max Temperature (C)", fontdict={"fontsize": 12})
plt.annotate(line_eq,(5,5),fontsize=15,color="red")
plt.title("Northern Hemisphere - Max Temp vs. Latitude Linear Regression", fontdict={"fontweight":"bold", "fontsize": 14})
plt.savefig("Northern_Hem Max_Temp v Latitude.png", dpi=200)
# Print r square value
print(f"The r-squared is: {rvalue**2}")

# Show plot
plt.show()
# Out:
# The r-squared is: 0.4782307903890464

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Create x and y values for Southern Hemisphere Temp and Latitude
x_values = southernhem_lat["Lat"]
y_values = southernhem_lat["Max Temp"]
# Perform a linear regression on max temperature vs. latitude
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

# Get regression values
regress_values = x_values * slope + intercept

# Create line equation string
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))

# Create Plot
plt.figure(figsize=(9,5))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")

# Label plot and annotate the line equation
plt.xlabel("Latitude", fontdict={"fontsize": 12})
plt.ylabel("Max Temperature (C)", fontdict={"fontsize": 12})
plt.annotate(line_eq,(-50,25),fontsize=15,color="red")
plt.title("Southern Hemisphere - Max Temp vs. Latitude Linear Regression", fontdict={"fontweight":"bold", "fontsize": 14})
plt.savefig("Southern_Hem Max_Temp v Latitude.png", dpi=200)
# Print r square value
print(f"The r-squared is: {rvalue**2}")

# Show plot
plt.show()
# Out:
# The r-squared is: 0.6087958956943705

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Create x and y values for Northern Hemisphere Humidity and Latitude
x_values = northernhem_lat["Lat"]
y_values = northernhem_lat["Humidity"]
# Perform a linear regression on max temperature vs. latitude
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

# Get regression values
regress_values = x_values * slope + intercept

# Create line equation string
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
  
# Create Plot
plt.figure(figsize=(9,5))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")

# Label plot and annotate the line equation
plt.xlabel("Latitude", fontdict={"fontsize": 12})
plt.ylabel("Humidity (%)", fontdict={"fontsize": 12})
plt.annotate(line_eq,(55,10),fontsize=15,color="red")
plt.title("Northern Hemisphere - Humidity(%) vs. Latitude Linear Regression", fontdict={"fontweight":"bold", "fontsize": 14})
plt.savefig("Northern_Hem Humidity v Latitude.png", dpi=200)
# Print r square value
print(f"The r-squared is: {rvalue**2}")

# Show plot
plt.show()
# Out:
# The r-squared is: 0.00048666539848916994

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Create x and y values for Southern Hemisphere Humidity and Latitude
x_values = southernhem_lat["Lat"]
y_values = southernhem_lat["Humidity"]
# Perform a linear regression on max temperature vs. latitude
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

# Get regression values
regress_values = x_values * slope + intercept

# Create line equation string
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))

# Create Plot
plt.figure(figsize=(9,5))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")

# Label plot and annotate the line equation
plt.xlabel("Latitude", fontdict={"fontsize": 12})
plt.ylabel("Humidity (%)", fontdict={"fontsize": 12})
plt.annotate(line_eq,(-50,40),fontsize=15,color="red")
plt.title("Southern Hemisphere - Humidity(%) vs. Latitude Linear Regression", fontdict={"fontweight":"bold", "fontsize": 14})
plt.savefig("Southern_Hem Humidity v Latitude.png", dpi=200)
# Print r square value
print(f"The r-squared is: {rvalue**2}")

# Show plot
plt.show()
# Out:
# The r-squared is: 0.027759988765788817

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Create x and y values for Northern Hemisphere Cloudiness and Latitude
x_values = northernhem_lat["Lat"]
y_values = northernhem_lat["Cloudiness"]
# Perform a linear regression on max temperature vs. latitude
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

# Get regression values
regress_values = x_values * slope + intercept

# Create line equation string
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
  
# Create Plot
plt.figure(figsize=(9,5))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")

# Label plot and annotate the line equation
plt.xlabel("Latitude", fontdict={"fontsize": 12})
plt.ylabel("Cloudiness (%)", fontdict={"fontsize": 12})
plt.annotate(line_eq,(2,10),fontsize=15,color="red")
plt.title("Northern Hemisphere - Cloudiness(%) vs. Latitude Linear Regression", fontdict={"fontweight":"bold", "fontsize": 14})
plt.savefig("Northern_Hem Cloudiness v Latitude.png", dpi=200)
# Print r square value
print(f"The r-squared is: {rvalue**2}")

# Show plot
plt.show()
# Out:
# The r-squared is: 2.8584543214359864e-11

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Create x and y values for Southern Hemisphere Cloudiness and Latitude
x_values = southernhem_lat["Lat"]
y_values = southernhem_lat["Cloudiness"]
# Perform a linear regression on max temperature vs. latitude
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

# Get regression values
regress_values = x_values * slope + intercept

# Create line equation string
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))

# Create Plot
plt.figure(figsize=(9,5))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")

# Label plot and annotate the line equation
plt.xlabel("Latitude", fontdict={"fontsize": 12})
plt.ylabel("Cloudiness (%)", fontdict={"fontsize": 12})
plt.annotate(line_eq,(-55,20),fontsize=15,color="red")
plt.title("Southern Hemisphere - Cloudiness(%) vs. Latitude Linear Regression", fontdict={"fontweight":"bold", "fontsize": 14})
plt.savefig("Southern_Hem Cloudiness v Latitude.png", dpi=200)
# Print r square value
print(f"The r-squared is: {rvalue**2}")

# Show plot
plt.show()
# Out:
# The r-squared is: 0.0002668025952717698

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Create x and y values for Northern Hemisphere Wind Speed and Latitude
x_values = northernhem_lat["Lat"]
y_values = northernhem_lat["Wind Speed"]
# Perform a linear regression on max temperature vs. latitude
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

# Get regression values
regress_values = x_values * slope + intercept

# Create line equation string
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
  
# Create Plot
plt.figure(figsize=(9,5))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")

# Label plot and annotate the line equation
plt.xlabel("Latitude", fontdict={"fontsize": 12})
plt.ylabel("Wind Speed (m/s)", fontdict={"fontsize": 12})
plt.annotate(line_eq,(48,10),fontsize=15,color="red")
plt.title("Northern Hemisphere - Wind Speed(m/s) vs. Latitude Linear Regression", fontdict={"fontweight":"bold", "fontsize": 14})
plt.savefig("Northern_Hem WindSpeed v Latitude.png", dpi=200)
# Print r square value
print(f"The r-squared is: {rvalue**2}")

# Show plot
plt.show()
# Out:
# The r-squared is: 0.030660380671036137

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Create x and y values for Southern Hemisphere Wind Speed and Latitude
x_values = southernhem_lat["Lat"]
y_values = southernhem_lat["Wind Speed"]
# Perform a linear regression on max temperature vs. latitude
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

# Get regression values
regress_values = x_values * slope + intercept

# Create line equation string
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))

# Create Plot
plt.figure(figsize=(9,5))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")

# Label plot and annotate the line equation
plt.xlabel("Latitude", fontdict={"fontsize": 12})
plt.ylabel("Wind Speed (m/s)", fontdict={"fontsize": 12})
plt.annotate(line_eq,(-50,10),fontsize=15,color="red")
plt.title("Southern Hemisphere - Wind Speed(m/s) vs. Latitude Linear Regression", fontdict={"fontweight":"bold", "fontsize": 14})
plt.savefig("Southern_Hem WindSpeed v Latitude.png", dpi=200)
# Print r square value
print(f"The r-squared is: {rvalue**2}")

# Show plot
plt.show()
# Out:
# The r-squared is: 0.01643156818090431
