# %% [markdown]
# # VacationPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import gmaps
import os
import json

# Import API key
from api_keys import g_key

# %% [markdown]
# ### Store Part I results into DataFrame
# * Load the csv exported in Part I to a DataFrame

# %%
clean_city_data = pd.read_csv("clean_city_data.csv")
clean_city_data
# Out:
#            City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0        Kitgum   3.28   32.89     18.34        91          35        1.63
# 1    Bredasdorp -34.53   20.04      9.00        93           0        2.10
# 2       Rikitea -23.12 -134.97     23.29        77          11        3.64
# 3      Iracoubo   5.48  -53.20     26.68        84          90        3.18
# 4           Vao -22.67  167.48     19.04        69          32        7.60
# ..          ...    ...     ...       ...       ...         ...         ...
# 546       Dubai  25.26   55.30     36.00        53          38        2.60
# 547         Sur  22.57   59.53     28.79        72          12        5.20
# 548        Lata  40.16   -8.33     19.44        72           0        2.68
# 549     Okhotsk  59.38  143.30     16.23        61           0        1.93
# 550    Bilibino  68.05  166.44      8.65        78         100        1.12
#
#     Country        Date
# 0        UG  1596317805
# 1        ZA  1596317806
# 2        PF  1596317668
# 3        GF  1596317669
# 4        NC  1596317669
# ..      ...         ...
# 546      AE  1596317731
# 547      OM  1596317805
# 548      PT  1596317614
# 549      RU  1596317805
# 550      RU  1596317805
#
# [551 rows x 9 columns]

# %% [markdown]
# ### Humidity Heatmap
# * Configure gmaps.
# * Use the Lat and Lng as locations and Humidity as the weight.
# * Add Heatmap layer to map.

# %%
# Configure gmaps
#gmaps.configure(api_keys=g_key)
gmaps.configure

# Store latitude and longitude in locations
locations = clean_city_data[["Lat", "Lng"]]

# Fill NaN values and convert to float
humidity = clean_city_data["Humidity"].astype(float)

# Plot heatmap
fig = gmaps.figure(map_type="TERRAIN")

# Create heat layer
heat_layer = gmaps.heatmap_layer(locations, weights=humidity,
                                dissipating =False, max_intensity=0,
                                point_radius=1)                                                                 
# Add layer
fig.add_layer(heat_layer)

# Display figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %% [markdown]
# ### Create new DataFrame fitting weather criteria
# * Narrow down the cities to fit weather conditions.
# * Drop any rows will null values.

# %%
# filter cities to a "perfect" temperature between 22 and 27 degrees celsius (70-80 F)
maxtemp_min = clean_city_data.loc[clean_city_data["Max Temp"] > 22]
maxtemp_max = maxtemp_min.loc[maxtemp_min["Max Temp"] < 27]

# filter cities even further for no clouds (close to zero %)
cloud = maxtemp_max.loc[maxtemp_max["Cloudiness"] < 5]

# filter cities even further for windspeeds of 4.5 m/s (less than 10mph)
windspeed = cloud.loc[cloud["Wind Speed"] < 4.5]

# filter cities even further for humidity under 56 %
humidity = windspeed.loc[windspeed["Humidity"] < 56]
humidity
# Out:
#                    City    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 22        Pozo Colorado -23.49  -58.80     26.33        41           3
# 85            Fairbanks  64.84 -147.72     25.00        50           1
# 119          Assiniboia  49.63 -105.98     26.01        29           0
# 421  Ribas do Rio Pardo -20.44  -53.76     24.35        38           0
# 465              Mizdah  31.45   12.98     23.81        40           0
# 485            Lüderitz -26.65   15.16     24.00        19           0
# 506              Morros  -9.45  -46.30     25.22        38           1
# 508             Changji  44.02   87.32     23.00        33           0
# 530             Jayanca  -6.39  -79.82     26.67        55           0
# 535           Beni Suef  29.07   31.10     26.88        41           0
#
#      Wind Speed Country        Date
# 22         2.56      PY  1596317673
# 85         0.78      US  1596317567
# 119        3.00      CA  1596317698
# 421        3.84      BR  1596317771
# 465        2.47      LY  1596317783
# 485        4.10     NaN  1596317789
# 506        2.51      BR  1596317794
# 508        2.00      CN  1596317795
# 530        2.24      PE  1596317801
# 535        3.99      EG  1596317802

# %% [markdown]
# ### Hotel Map
# * Store into variable named `hotel_df`.
# * Add a "Hotel Name" column to the DataFrame.
# * Set parameters to search for hotels with 5000 meters.
# * Hit the Google Places API for each city's coordinates.
# * Store the first Hotel result into the DataFrame.
# * Plot markers on top of the heatmap.

# %%
#  rename and add hotel name to dataframe column
hotel_df = humidity
hotel_df["Hotel Name"] = ""
hotel_df.head(15)
# Out:
# /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#                    City    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 22        Pozo Colorado -23.49  -58.80     26.33        41           3
# 85            Fairbanks  64.84 -147.72     25.00        50           1
# 119          Assiniboia  49.63 -105.98     26.01        29           0
# 421  Ribas do Rio Pardo -20.44  -53.76     24.35        38           0
# 465              Mizdah  31.45   12.98     23.81        40           0
# 485            Lüderitz -26.65   15.16     24.00        19           0
# 506              Morros  -9.45  -46.30     25.22        38           1
# 508             Changji  44.02   87.32     23.00        33           0
# 530             Jayanca  -6.39  -79.82     26.67        55           0
# 535           Beni Suef  29.07   31.10     26.88        41           0
#
#      Wind Speed Country        Date Hotel Name
# 22         2.56      PY  1596317673
# 85         0.78      US  1596317567
# 119        3.00      CA  1596317698
# 421        3.84      BR  1596317771
# 465        2.47      LY  1596317783
# 485        4.10     NaN  1596317789
# 506        2.51      BR  1596317794
# 508        2.00      CN  1596317795
# 530        2.24      PE  1596317801
# 535        3.99      EG  1596317802

# %%
#set parameter to search hotel within 5000 meters and hit google places API for call's based on coordinates

#  params dictionary to update each iteration 
params = {
    "radius": 5000,
    "type": "lodging",
    "key": g_key
}
# Use the lat/lng to identify hotels
for index, row in hotel_df.iterrows():
    
    # get lat, lng from df
    lat = row["Lat"]
    lng = row["Lng"]
    
    # change location each iteration while leaving original params in place
    params["location"] = f"{lat},{lng}"
    
    # use search term: "hotel" and our lat/lng
    base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
    
    # make reguest
    name = requests.get(base_url, params=params)
    
    # convert to json
    name = name.json()
    
    #print to confirm data
    print(json.dumps(name, indent=4, sort_keys= True))
     
    # use try and except to skip any missing data points
    try:
        hotel_df.loc[index, "Hotel Name"] = name["results"][0]["name"]
    except:
        print("Missing...skipping")
# Out:
# {
#     "html_attributions": [],
#     "results": [
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -23.4930127,
#                     "lng": -58.7964245
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -23.49152266970849,
#                         "lng": -58.79507691970849
#                     },
#                     "southwest": {
#                         "lat": -23.4942206302915,
#                         "lng": -58.79777488029151
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "name": "Hospedaje la Amistad",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 2448,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/104612068677889858433\">ELMURA</a>"
#                     ],
#                     "photo_reference": "CmRaAAAArwnEYNVsvQ0CrmVzpoN0Pg7AY9xDF8tN5idmvQdBEWLVzZWIdJ0Z4rntk1zveTwgjXhX2n-vUld13MRugQ_5IT8cD74Uk8q3v6Yr_mCPzeuTsSZVhS6t90SgfZukysupEhD1QjTkAkfRMVahNZ1FXAgeGhR4jPrOWpWU1vH1WT7f7AxmHKLwtw",
#                     "width": 3264
#                 }
#             ],
#             "place_id": "ChIJZZmFkac5b5QRpL27ffZFInw",
#             "plus_code": {
#                 "compound_code": "G643+QC Pozo Colorado, Paraguay",
#                 "global_code": "5883G643+QC"
#             },
#             "rating": 3.7,
#             "reference": "ChIJZZmFkac5b5QRpL27ffZFInw",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 59,
#             "vicinity": "Pozo Colorado"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -23.4931181,
#                     "lng": -58.79622939999999
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -23.4917180697085,
#                         "lng": -58.79479261970848
#                     },
#                     "southwest": {
#                         "lat": -23.4944160302915,
#                         "lng": -58.79749058029149
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "2a968b983b3848b9b253ed8f5ac2b504bbd86009",
#             "name": "Hotel Marriot \u2b50\ufe0f\u2b50\ufe0f\u2b50\ufe0f\u2b50\ufe0f",
#             "photos": [
#                 {
#                     "height": 4160,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/104612068677889858433\">ELMURA</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAdlLJ_dpU9lXOzTt-CGS_bwJmr_5Y6DqXbteGni5PYeV5UqgBu9sbY2kylXNmEDcyBZKb_czP7yhFWWpi3fvmqKgXYuYMxywS7QPYzXzEUdT2Cr_fGY7LnGEZuibwcwcwEhAsLvzjgNEkYIxNHfhFP6ZmGhQhXSqMRu2QjzfvavGUAY2UY7IS_g",
#                     "width": 3120
#                 }
#             ],
#             "place_id": "ChIJ52mIv0A5b5QRnilovKg7y40",
#             "plus_code": {
#                 "compound_code": "G643+QG Pozo Colorado, Paraguay",
#                 "global_code": "5883G643+QG"
#             },
#             "rating": 5,
#             "reference": "ChIJ52mIv0A5b5QRnilovKg7y40",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 2,
#             "vicinity": "Pozo Colorado"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -23.49209029999999,
#                     "lng": -58.7943
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -23.49090371970849,
#                         "lng": -58.79321571970849
#                     },
#                     "southwest": {
#                         "lat": -23.4936016802915,
#                         "lng": -58.79591368029151
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "67c3d0d6ec227cad77b537f19fe0052d1fcd33bb",
#             "name": "Hotel Pozo Colorado",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 1836,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/

#                     "width": 2880
#                 }
#             ],
#             "place_id": "ChIJT-dDItNaMlERceI78TmVRjU",
#             "plus_code": {
#                 "compound_code": "R6VJ+53 Fairbanks, AK, USA",
#                 "global_code": "93PJR6VJ+53"
#             },
#             "rating": 4.1,
#             "reference": "ChIJT-dDItNaMlERceI78TmVRjU",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 587,
#             "vicinity": "1908 Chena Landing Loop, Fairbanks"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 64.8347058,
#                     "lng": -147.7261844
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 64.8361113802915,
#                         "lng": -147.7254946197085
#                     },
#                     "southwest": {
#                         "lat": 64.83341341970849,
#                         "lng": -147.7281925802915
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "name": "Fairbanks Downtown Bed & Breakfast",
#             "photos": [
#                 {
#                     "height": 551,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/105813231428729399737\">Chandra Simpson</a>"
#                     ],
#                     "photo_reference": "CmRZAAAAfnKbhQ44f29MDPvWGQc5_CHFV2v-uZuucajzK3zufNPWiLBdUbAQ6jIIf_hR2oxeFJ0YR74pX0p1bkRPP9Djnds5QyXZjLMENS_PUFhUjMjxX6_1Uc1HFvEPS81GFcS6EhBapKKo-g142vv8WbZzY91EGhQEib0_8wCpbGdzdJhG6hy-KGCSvQ",
#                     "width": 406
#                 }
#             ],
#             "place_id": "ChIJpyS4pkxFMlERZ8ikGNmGAWY",
#             "plus_code": {
#                 "compound_code": "R7MF+VG Fairbanks, AK, USA",
#                 "global_code": "93PJR7MF+VG"
#             },
#             "rating": 4.7,
#             "reference": "ChIJpyS4pkxFMlERZ8ikGNmGAWY",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 3,
#             "vicinity": "1461 Gillam Way, Fairbanks"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 64.8596884,
#                     "lng": -147.7014315
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 64.86119963029151,
#                         "lng": -147.69911435
#                     },
#                     "southwest": {
#                         "lat": 64.8585016697085,
#                         "lng": -147.70356655
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "04b43bee09b4f89c8d8ae1e2c443fe7b4455582e",
#             "name": "Hampton Inn & Suites Fairbanks",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 1673,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/106995606913792852627\">Hampton Inn &amp; Suites Fairbanks</a>"
#                     ],
#                     "photo_reference": "CmRaAAAA1mQpsyxGFwaTKkG3IZxzSexI5jwDgTq0oCEuUoY4MgkPuGt7DvUNet-lLlHAuyJcviBGxKo0qHHv7gwJ07aMraJJaQa0rRBPTElIwnK4DLNKl9gQqAKh_zAsMhEYzibSEhB1nil3AMamdSS7PLcT7f6XGhRyWjpunlC1YPcISHwbTdXsx9RkfA",
#                     "width": 2048
#                 }
#             ],
#             "place_id": "ChIJ1UJ4S2tFMlERZtFPtmfCrm8",
#             "plus_code": {
#                 "compound_code": "V75X+VC Fairbanks, AK, USA",
#                 "global_code": "93PJV75X+VC"
#             },
#             "rating": 4.4,
#             "reference": "ChIJ1UJ4S2tFMlERZtFPtmfCrm8",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 322,
#             "vicinity": "433 Harold Bentley Avenue, Fairbanks"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 64.83763499999999,
#                     "lng": -147.8234906
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 64.8389100802915,
#                         "lng": -147.8225395197085
#                     },
#                     "southwest": {
#                         "lat": 64.83621211970849,
#                         "lng": -147.8252374802915
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "f53548c9c1a1016d7c1b8104f1d48db0fb02305a",
#             "name": "Best Western Plus Chena River Lodge",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 2559,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/103930524753241407861\">Best Western Plus Chena River Lodge</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAACntHeHuwSkbddAAdOJc9zLjtIXxQuFT24ysNF5RJ_7uGnv54JVBCT7I3Op5zeclJPKszvT61tyBa1izNEUCnUKs4NGqTEmUQAJ5iUfTsfMMpWglTCwiFJwlPwbt9B42EhBEP87Pz76louBXqIk7tWVmGhQuAqn-rwBAcgjU4PyO6nol0tL5jg",
#                     "width": 3839
#                 }
#             ],
#             "place_id": "ChIJ5T7ffSRbMlERW-D1ice5dBI",
#             "plus_code": {
#                 "compound_code": "R5QG+3J Fairbanks, AK, USA",
#                 "global_code": "93PJR5QG+3J"
#             },
#             "rating": 4.1,
#             "reference": "ChIJ5T7ffSRbMlERW-D1ice5dBI",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total":

#             },
#             "rating": 4.3,
#             "reference": "ChIJ64hhFstaMlERoK428ftHn5U",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 19,
#             "vicinity": "1500 Airport Way C, Fairbanks"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 64.8492281,
#                     "lng": -147.7182109
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 64.8506655802915,
#                         "lng": -147.7168092697085
#                     },
#                     "southwest": {
#                         "lat": 64.8479676197085,
#                         "lng": -147.7195072302915
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "name": "Minnie Street Inn",
#             "photos": [
#                 {
#                     "height": 4032,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/108412411814154290022\">Minnie Street Inn</a>"
#                     ],
#                     "photo_reference": "CmRaAAAA16CxWwTGcyBP2Qvz3PFaKDguzEWAaU6uJNCxfcZKq3m5iaLEejPejm7eTmbia9JtWhR0JKnvp9iNAcqgmXolsdiBmtzClw4xyWxoTArxib__gxyiorv9epEeyQXhy0OwEhBvDDk9yIyqRb7-m7BLJbN0GhR1OZmM4raeensPJ7HNcswFm-aF_g",
#                     "width": 3024
#                 }
#             ],
#             "place_id": "ChIJRa2PZUdFMlER-7_E7Tp7iNI",
#             "plus_code": {
#                 "compound_code": "R7XJ+MP Fairbanks, AK, USA",
#                 "global_code": "93PJR7XJ+MP"
#             },
#             "rating": 4.2,
#             "reference": "ChIJRa2PZUdFMlER-7_E7Tp7iNI",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 33,
#             "vicinity": "345 Minnie Street, Fairbanks"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 64.834924,
#                     "lng": -147.8069015
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 64.83637008029152,
#                         "lng": -147.8055519697085
#                     },
#                     "southwest": {
#                         "lat": 64.8336721197085,
#                         "lng": -147.8082499302915
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "46d7f3e838cfa709e98feaf2c2671bef40ec3f96",
#             "name": "Rewak Studios",
#             "place_id": "ChIJyxXraCdbMlERjlaymMaGDJE",
#             "plus_code": {
#                 "compound_code": "R5MV+X6 Fairbanks, AK, USA",
#                 "global_code": "93PJR5MV+X6"
#             },
#             "rating": 3.7,
#             "reference": "ChIJyxXraCdbMlERjlaymMaGDJE",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 15,
#             "vicinity": "3483 Rewak Drive, Fairbanks"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 64.8312875,
#                     "lng": -147.81062
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 64.83360155,
#                         "lng": -147.80993305
#                     },
#                     "southwest": {
#                         "lat": 64.83051615000001,
#                         "lng": -147.81268085
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "name": "Sophie Station Suites",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 3024,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/113495488395279705403\">Treavor Mattson</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAdpGNFuBWfQ_Kdh30MNH2utc2SJP7Fq4oQEAtAfBlvmIlp2BIY_qZtlkAuXIa2DnhqDlqKGz8ynBD8Keyd2IT5iHab3iixxwm7ZiqkrgDcDbFwIpCO2pp9x-fD1fSzbTuEhC8WBsq4-JV_dYrLfBpifDnGhQVYuZYHmBTM8DFtkcHKvbSNoFI1A",
#                     "width": 4032
#                 }
#             ],
#             "place_id": "ChIJM0CuxsxEMlERigcusSQX1k4",
#             "plus_code": {
#                 "compound_code": "R5JQ+GQ Fairbanks, AK, USA",
#                 "global_code": "93PJR5JQ+GQ"
#             },
#             "rating": 4.4,
#             "reference": "ChIJM0CuxsxEMlERigcusSQX1k4",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "bar",
#                 "restaurant",
#                 "food",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 374,
#             "vicinity": "1717 University Avenue South, Fairbanks"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 64.83589169999999,
#                     "lng": -147.8242492
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 64.8369215302915,
#                         "lng": -147.8226329697085
#                     },
#                     "southwest": {
#                         "lat": 64.8342235697085,
#                         "lng": -147.8253309302915
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "8a46b88a6879c1d2f3b3bcf6391ea1f8d9bce5b3",
#             "name": "Extended Stay America - Fairbanks - Old Airport Way",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 2160,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/115518183988878826568\">Extended Stay America - Fairbanks - Old Airport Way</a>"
#                     ],
#                     "photo_reference": "CmRaAAAApWUoPku8zMaP5R5hvqf6jytJpuukUA4TXR1puEo3mBPrs6MUmOPq6CgZVdW_1cpXwTIuXmy1i7fVdFbpGBzm4UNNWubISjahGqXk2fIIb71S6WxJE4mO9jnl37y16su6EhDCcImcGgw5-kXkUZfDwxheGhSsHrI5HOTmOZXlUxmwAGM9buuR3A",
#                     "width": 2880
#                 }
#             ],
#             "place_id": "ChIJqbFJVhdbMlERYHgGtF-Gv8w",
#             "plus_code": {
#                 "compound_code": "R5PG+98 Fairbanks, AK, USA",
#                 "global_code": "93PJR5PG+98"
#             },
#             "rating": 3.1,
#             "reference": "ChIJqbFJVhdbMlERYHgGtF-Gv8w",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 239,
#             "vicinity": "4580 Old Airport Road, Fairbanks"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 64.8351528,
#                     "lng": -147.7162472
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 64.83650098029149,
#                         "lng": -147.7146403197085
#                     },
#                     "southwest": {
#                         "lat": 64.83380301970848,
#                         "lng": -147.7173382802915
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "ef08e2434c107270951795ba166ef6fce048f940",
#             "name": "Brennan's B&B",
#             "photos": [
#                 {
#                     "height": 810,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/113546910777926782170\">Behati Total Body</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAAuC5M1Ti9fJ_xLCsfVjh6Ox_VwCswEZkFHq4wukprXgyKHw_NX-eDFHa6vjFnQhxAD6wNkrL-EIrC0YrxNaIIJ0qQtK7XVcvmEI4ViTsme8BWFn3xoyhprulTH8pBtCQEhD_TIwjBAR09fFz9UsuAonMGhQEyF0tfUBDBDpJfChTsB84ImK2kA",
#                     "width": 1080
#                 }
#             ],
#             "place_id": "ChIJAQDMpE1FMlERbpoq3hbjm6k",
#             "plus_code": {
#                 "compound_code": "R7PM+3G Fairbanks, AK, USA",
#                 "global_code": "93PJR7PM+3G"
#             },
#             "rating": 5,
#             "reference": "ChIJAQDMpE1FMlERbpoq3hbjm6k",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 1,
#             "vicinity": "1430 Lacey Street, Fairbanks"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 64.819932,
#                     "lng": -147.777481
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 64.82129163029151,
#                         "lng": -147.7766211697085
#                     },
#                     "southwest": {
#                         "lat": 64.81859366970849,
#                         "lng": -147.7793191302915
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/generic_business-71.png",
#             "id": "f1287f789e9bb106dab1b71986b1f40a4e6fb10e",
#             "name": "Arctic RV",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "place_id": "ChIJY2WE3MFaMlERjhoBEwpPr_k",
#             "plus_code": {
#                 "compound_code": "R69F+X2 Fairbanks, AK, USA",
#                 "global_code": "93PJR69F+X2"
#             },
#             "rating": 3.9,
#             "reference": "ChIJY2WE3MFaMlERjhoBEwpPr_k",
#             "scope": "GOOGLE",
#             "types": [
#                 "rv_park",
#                 "car_repair",
#                 "lodging",
#                 "point_of_interest",
#                 "store",
#                 "establishment"
#             ],
#             "user_ratings_total": 60,
#             "vicinity": "3013 Peger Road, Fairbanks"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 64.8277362,
#                     "lng": -147.7271221
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 64.82894778029151,
#                         "lng": -147.7257761197085
#                     },
#                     "southwest": {
#                         "lat": 64.8262498197085,
#                         "lng": -147.7284740802915
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "c883a06b9b1cc43604fc00867fc4fdee9aed0501",
#             "name": "Alaska Heritage Hostel",
#             "photos": [
#                 {
#                     "height": 3024,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/103516209694735113699\">P.Q. Z</a>"
#                     ],
#                     "photo_reference": "CmRaAAAA6qIEsR-vgipO2JnLqrHpMQEt0fE-GLMf_oa7B8llvZbjik4xadG3YZh0EmKao6B0j1Rchye26NCre12n2I_q-6AChteL2KjpbkVHPiZUo9JcXhCMDzAmE5mNB6XNGxXdEhDs6UB8h-Zox-i6CiITA_9QGhSu-0jfcIfJmR8BCvcjiks5gerOig",
#                     "width": 4032
#                 }
#             ],
#             "place_id": "ChIJzd8OGLJaMlER3itUq73s96s",
#             "plus_code": {
#                 "compound_code": "R7HF+35 Fairbanks, AK, USA",
#                 "global_code": "93PJR7HF+35"
#             },
#             "rating": 4.7,
#             "reference": "ChIJzd8OGLJaMlER3itUq73s96s",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 3,
#             "vicinity": "1018 22nd Avenue, Fairbanks"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 64.8377534,
#                     "lng": -147.7500308
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 64.8392536302915,
#                         "lng": -147.7486428197085
#                     },
#                     "southwest": {
#                         "lat": 64.83655566970849,
#                         "lng": -147.7513407802915
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "603564ece3dac679037c17e69f5eb7e4dd202c4d",
#             "name": "BOREALIS STAY",
#             "place_id": "ChIJZ9RQQMtaMlERlijwN-AM68M",
#             "plus_code": {
#                 "compound_code": "R6QX+4X Fairbanks, AK, USA",
#                 "global_code": "93PJR6QX+4X"
#             },
#             "rating": 3.7,
#             "reference": "ChIJZ9RQQMtaMlERlijwN-AM68M",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 7,
#             "vicinity": "1521 Hilton Avenue, Fairbanks"
#         }
#     ],
#     "status": "OK"
# }
# {
#     "html_attributions": [],
#     "results": [
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 49.6345024,
#                     "lng": -106.0031738
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 49.63606378029151,
#                         "lng": -106.0018083197085
#                     },
#                     "southwest": {
#                         "lat": 49.63336581970851,
#                         "lng": -106.0045062802915
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "822c5459174474d53799edc14afa6fe9f0377a97",
#             "name": "Canalta Hotel Assiniboia",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 2048,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/117948192971124681168\">Canalta Hotel Assiniboia</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAw8eI84taMgctPbgOKJ0xfrylpYjwL5rc1ddXETWXdSouEmjYjVrNziMO61RPS4AVWTuDGO_yMzsiDB2acTH6yvwBlR8Y-1bfPqdGrI132UuFedh6u9CK7ecO5gayeFLGEhCcHKvKH6ea4n0-b7dAkCT_GhQvCgU77hrUcAnLeoNUlgm_0jnF-Q",
#                     "width": 1993
#                 }
#             ],
#             "place_id": "ChIJAwroBQ7KGVMRDwgKWqJoXZU",
#             "plus_code": {
#                 "compound_code": "JXMW+RP Assiniboia, SK, Canada",
#                 "global_code": "85XMJXMW+RP"
#             },
#             "rating": 4.5,
#             "reference": "ChIJAwroBQ7KGVMRDwgKWqJoXZU",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 99,
#             "vicinity": "601 1 Avenue West, Assiniboia"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 49.63293840000001,
#                     "lng": -105.9885191
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 49.63440808029151,
#                         "lng": -105.9871358697085
#                     },
#                     "southwest": {
#                         "lat": 49.63171011970851,
#                         "lng": -105.9898338302915
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "name": "Bar B Motel",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 4912,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/104938408694096221910\">Bar B Motel</a>"
#                     ],
#                     "photo_reference": "CmRaAAAA-dptwilCHH2oe0EUvy8DsA3MxyJ4_gFSOyghn9G4b-zIojhpciyNLBI_x0oh_1BDTB1zl1XBdbfoq7HETg5aTZ2y0OQwy98P7XB-vTa853nBL7Uyjmyv3aG9dYQaVyQGEhDIO5fSLZvx8uVT2TJP-WJZGhRMG7xZTZJ0lnWwq33lntudvnw8uQ",
#                     "width": 7360
#                 }
#             ],
#             "place_id": "ChIJv2C1WW3KGVMRlAoEcWvxwqA",
#             "plus_code": {
#                 "compound_code": "J2M6+5H Assiniboia, SK, Canada",
#                 "global_code": "85XPJ2M6+5H"
#             },
#             "rating": 4.4,
#             "reference": "ChIJv2C1WW3KGVMRlAoEcWvxwqA",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 17,
#             "vicinity": "200 1 Avenue East, Assiniboia"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 49.6334358,
#                     "lng": -105.9915203
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 49.6348030302915,
#                         "lng": -105.9903298697085
#                     },
#                     "southwest": {
#                         "lat": 49.6321050697085,
#                         "lng": -105.9930278302915
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "name": "Franklin Hotel & Motel",
#             "photos": [
#                 {
#                     "height": 3024,
# ...
#             "name": "\u064a\u0648\u0633\u0641 \u0627\u062d\u0645\u062f \u0633\u0639\u062f",
#             "place_id": "ChIJMUxRweonWhQR6g2nNH6Q-DU",
#             "plus_code": {
#                 "compound_code": "3483+M3 Beni Suef, Qism Bani Sweif, Bani Sweif, Egypt",
#                 "global_code": "7GXH3483+M3"
#             },
#             "reference": "ChIJMUxRweonWhQR6g2nNH6Q-DU",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "vicinity": "\u0634\u0631\u0639 \u0627\u0644\u0631\u0648\u0636\u0629"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 29.067147,
#                     "lng": 31.0966676
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 29.0684892802915,
#                         "lng": 31.0979977802915
#                     },
#                     "southwest": {
#                         "lat": 29.0657913197085,
#                         "lng": 31.0952998197085
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "name": "\u0627\u0644\u0634\u064a\u062e \u0627\u062d\u0645\u062f \u0627\u0644\u0645\u0634\u0631\u0642\u064a",
#             "photos": [
#                 {
#                     "height": 2048,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/115218399218539557700\">Eng ALI HASSAN</a>"
#                     ],
#                     "photo_reference": "CmRaAAAADt8bWqQqcqxthG5Q-IboEUT7nX4KTu6VuFU1ZDxEu5uKyVTG-WHx03AApOzBkrhqdB822CB-e_a_-zGGMVs9E8OmIwFC924rxcKyuSOpeM3fR0ihAxG-1x5c07_sd2CXEhBOXMI5cpwMLmIyywgCsLAkGhTFsIR0fB2gzAK6O2wB1WxxHbkI2w",
#                     "width": 1152
#                 }
#             ],
#             "place_id": "ChIJoeZJXdwlWhQRvDQm1D9XUJ4",
#             "plus_code": {
#                 "compound_code": "338W+VM Beni Suef, Qism Bani Sweif, Bani Sweif, Egypt",
#                 "global_code": "7GXH338W+VM"
#             },
#             "reference": "ChIJoeZJXdwlWhQRvDQm1D9XUJ4",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "vicinity": "\u0634\u0627\u0631\u0639 \u0627\u0644\u0645\u0646\u0635\u0648\u0631\u060c \u0642\u0633\u0645 \u0628\u0646\u064a \u0633\u0648\u064a\u0641\u060c \u0628\u0646\u064a \u0633\u0648\u064a\u0641\u060c \u0645\u062d\u0627\u0641\u0638\u0629 \u0628\u0646\u064a \u0633\u0648\u064a\u0641\u060c"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 29.069572,
#                     "lng": 31.095057
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 29.07093618029149,
#                         "lng": 31.09645013029149
#                     },
#                     "southwest": {
#                         "lat": 29.0682382197085,
#                         "lng": 31.09375216970849
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "f49c935e7749998db22da0265314993a9548d1d6",
#             "name": "\u0628\u0631\u062c \u0633\u0648\u0644\u064a\u062a\u064a\u0631",
#             "place_id": "ChIJ1fXNrWgnWhQRg37RuURK_sg",
#             "plus_code": {
#                 "compound_code": "339W+R2 Beni Suef, Qism Bani Sweif, Bani Sweif, Egypt",
#                 "global_code": "7GXH339W+R2"
#             },
#             "rating": 5,
#             "reference": "ChIJ1fXNrWgnWhQRg37RuURK_sg",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 1,
#             "vicinity": "\u0634\u0627\u0631\u0639 \u0634\u0627\u0647\u064a\u0646\u060c \u0642\u0633\u0645 \u0628\u0646\u064a \u0633\u0648\u064a\u0641\u060c \u0628\u0646\u064a \u0633\u0648\u064a\u0641\u060c \u0645\u062d\u0627\u0641\u0638\u0629 \u0628\u0646\u064a \u0633\u0648\u064a\u0641\u060c"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 29.067906,
#                     "lng": 31.1056608
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 29.0692582302915,
#                         "lng": 31.1070015802915
#                     },
#                     "southwest": {
#                         "lat": 29.0665602697085,
#                         "lng": 31.1043036197085
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "name": "\u0628\u0631\u062c \u0627\u0644\u062a\u0648\u062d\u064a\u062f \u0627\u0644\u0633\u0639\u0648\u062f\u064a",
#             "place_id": "ChIJE0nP4vsnWhQRdTGrbaHjCBo",
#             "plus_code": {
#                 "compound_code": "3494+57 Beni Suef, Qism Bani Sweif, Bani Sweif, Egypt",
#                 "global_code": "7GXH3494+57"
#             },
#             "reference": "ChIJE0nP4vsnWhQRdTGrbaHjCBo",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "vicinity": "\u0642\u0633\u0645 \u0628\u0646\u064a \u0633\u0648\u064a\u0641\u060c \u0628\u0646\u064a \u0633\u0648\u064a\u0641\u060c \u0645\u062d\u0627\u0641\u0638\u0629 \u0628\u0646\u064a \u0633\u0648\u064a\u0641\u060c"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 29.067853,
#                     "lng": 31.105904
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 29.0691817302915,
#                         "lng": 31.1072474302915
#                     },
#                     "southwest": {
#                         "lat": 29.0664837697085,
#                         "lng": 31.1045494697085
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "6e715dd8719e01314da5fedd541e3523fc6845bc",
#             "name": "\u0627\u0628\u0631\u0627\u062c \u0632\u0645\u0632\u0645",
#             "photos": [
#                 {
#                     "height": 4128,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/100029847897598370067\">Mahmoud Sayed</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAMP6jo8jQYP4cD7i7hR192r0F8wZcCh_RlZKuK7zGP8-az7_YgPU8nQmfw2LeSX7VeGHm9Y7n7KUwPo3pa72oVCfPkLFGBiokT1n8uo3Bgy_CIqwQ1uUVUtpMjw6rBsN9EhDad_bz_wxV49g4Nh3XXABxGhTQrAAlXJwN5R1NivLf7bIb2BO--w",
#                     "width": 3096
#                 }
#             ],
#             "place_id": "ChIJqTzEbaEnWhQRYMS-EhBT2UA",
#             "plus_code": {
#                 "compound_code": "3494+49 Beni Suef, Qism Bani Sweif, Bani Sweif, Egypt",
#                 "global_code": "7GXH3494+49"
#             },
#             "rating": 1,
#             "reference": "ChIJqTzEbaEnWhQRYMS-EhBT2UA",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 1,
#             "vicinity": "\u0642\u0633\u0645 \u0628\u0646\u064a \u0633\u0648\u064a\u0641\u060c \u0628\u0646\u064a \u0633\u0648\u064a\u0641\u060c \u0645\u062d\u0627\u0641\u0638\u0629 \u0628\u0646\u064a \u0633\u0648\u064a\u0641\u060c\u060c \u0642\u0633\u0645 \u0628\u0646\u064a \u0633\u0648\u064a\u0641\u060c \u0628\u0646\u0649 \u0633\u0648\u064a\u0641\u060c \u0645\u062d\u0627\u0641\u0638\u0629 \u0628\u0646\u064a \u0633\u0648\u064a\u0641\u060c"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 29.07200370000001,
#                     "lng": 31.1059795
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 29.0733713802915,
#                         "lng": 31.1073259802915
#                     },
#                     "southwest": {
#                         "lat": 29.0706734197085,
#                         "lng": 31.1046280197085
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "f1d16841fa96ab5ed347ad4f23f0c3b9a370ccb8",
#             "name": "\u0645\u0628\u0646\u0649 \u0627\u0644\u0628\u0631\u062c \u0627\u0644\u062b\u0627\u0646\u0649 \u0644\u0644\u0634\u0631\u0637\u0647 \u0627\u0644\u0639\u0633\u0643\u0631\u064a\u0647",
#             "place_id": "ChIJJ4etd54nWhQRsTVAbfjp6gE",
#             "plus_code": {
#                 "compound_code": "34C4+R9 Qism Bani Sweif, Bani Sweif, Egypt",
#                 "global_code": "7GXH34C4+R9"
#             },
#             "rating": 5,
#             "reference": "ChIJJ4etd54nWhQRsTVAbfjp6gE",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 1,
#             "vicinity": "Ahmed Farag, Qism Bani Sweif"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 29.0757593,
#                     "lng": 31.10154559999999
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 29.07716578029149,
#                         "lng": 31.1028991802915
#                     },
#                     "southwest": {
#                         "lat": 29.0744678197085,
#                         "lng": 31.1002012197085
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "name": "\u0645\u0637\u0639\u0645 \u0643\u0644\u0627\u0628 \u0648\u0642\u0637\u0637",
#             "place_id": "ChIJ2UesTXMnWhQRhiz2c_3jgB4",
#             "plus_code": {
#                 "compound_code": "34G2+8J Qism Bani Sweif, Bani Sweif, Egypt",
#                 "global_code": "7GXH34G2+8J"
#             },
#             "reference": "ChIJ2UesTXMnWhQRhiz2c_3jgB4",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "vicinity": "Qism Bani Sweif, Bani Sweif"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 29.07288,
#                     "lng": 31.1059099
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 29.0742133802915,
#                         "lng": 31.1072620302915
#                     },
#                     "southwest": {
#                         "lat": 29.0715154197085,
#                         "lng": 31.1045640697085
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "name": "\u0628\u0631\u062c \u0627\u0644\u0639\u0631\u0628",
#             "place_id": "ChIJJ4Xee2YnWhQRiuKiMSRK_gs",
#             "plus_code": {
#                 "compound_code": "34F4+59 Beni Suef, Egypt",
#                 "global_code": "7GXH34F4+59"
#             },
#             "reference": "ChIJJ4Xee2YnWhQRiuKiMSRK_gs",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "vicinity": "Unnamed Road, \u0642\u0633\u0645 \u0628\u0646\u064a \u0633\u0648\u064a\u0641\u060c \u0628\u0646\u064a \u0633\u0648\u064a\u0641\u060c\u060c \u0642\u0633\u0645 \u0628\u0646\u064a \u0633\u0648\u064a\u0641\u060c \u0628\u0646\u0649 \u0633\u0648\u064a\u0641\u060c \u0645\u062d\u0627\u0641\u0638\u0629 \u0628\u0646\u064a \u0633\u0648\u064a\u0641\u060c"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 29.0765001,
#                     "lng": 31.100293
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 29.0779681802915,
#                         "lng": 31.1016479302915
#                     },
#                     "southwest": {
#                         "lat": 29.0752702197085,
#                         "lng": 31.0989499697085
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "0143057a3120a2d18a663cfd9a6a2ecf467e4c10",
#             "name": "\u0641\u0646\u062f\u0642 \u062c\u0631\u0627\u0646\u062f \u0633\u0648\u064a\u062a",
#             "place_id": "ChIJMVPxZponWhQRrzjq--ZC4U0",
#             "plus_code": {
#                 "compound_code": "34G2+J4 Qism Bani Sweif, Bani Sweif, Egypt",
#                 "global_code": "7GXH34G2+J4"
#             },
#             "rating": 3.5,
#             "reference": "ChIJMVPxZponWhQRrzjq--ZC4U0",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 2,
#             "vicinity": "Ibn Roshd, Qism Bani Sweif, Bani Sweif"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 29.0635879,
#                     "lng": 31.101381
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 29.0651014302915,
#                         "lng": 31.1023633802915
#                     },
#                     "southwest": {
#                         "lat": 29.0624034697085,
#                         "lng": 31.0996654197085
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "name": "\u0641\u0646\u062f\u0642 \u0627\u0644\u0642\u0648\u0627\u062a \u0627\u0644\u0645\u0633\u0644\u062d\u0647",
#             "photos": [
#                 {
#                     "height": 1080,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/103714202831302524643\">Fady Kamal</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAfEZSBI_rgTkKSwypATTROAgfpNeH4J94hfd5H-MYMkwtqktUWLDZW6NpTrY7APyFxxaS8aIuEeD43sfYGM1yGzmfYb50apDfJLCq1iC_xf5yoP0TQ3N--6j-5GgL9F-PEhDYb_SUCzp2dSWInN3voVYbGhQ2xVlkN-xSwrKw-CgaULNSmbbBfQ",
#                     "width": 1920
#                 }
#             ],
#             "place_id": "ChIJNQzUieAlWhQRHmpDTaY1HB4",
#             "plus_code": {
#                 "compound_code": "3472+CH Qism Bani Sweif, Bani Sweif, Egypt",
#                 "global_code": "7GXH3472+CH"
#             },
#             "rating": 3.7,
#             "reference": "ChIJNQzUieAlWhQRHmpDTaY1HB4",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 138,
#             "vicinity": "Qism Bani Sweif, Bani Sweif"
#         }
#     ],
#     "status": "OK"
# }

# %%
# confirm hotel name data appears in dataframe
hotel_df.head(15)
# Out:
#                    City    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 22        Pozo Colorado -23.49  -58.80     26.33        41           3
# 85            Fairbanks  64.84 -147.72     25.00        50           1
# 119          Assiniboia  49.63 -105.98     26.01        29           0
# 421  Ribas do Rio Pardo -20.44  -53.76     24.35        38           0
# 465              Mizdah  31.45   12.98     23.81        40           0
# 485            Lüderitz -26.65   15.16     24.00        19           0
# 506              Morros  -9.45  -46.30     25.22        38           1
# 508             Changji  44.02   87.32     23.00        33           0
# 530             Jayanca  -6.39  -79.82     26.67        55           0
# 535           Beni Suef  29.07   31.10     26.88        41           0
#
#      Wind Speed Country        Date  \
# 22         2.56      PY  1596317673
# 85         0.78      US  1596317567
# 119        3.00      CA  1596317698
# 421        3.84      BR  1596317771
# 465        2.47      LY  1596317783
# 485        4.10     NaN  1596317789
# 506        2.51      BR  1596317794
# 508        2.00      CN  1596317795
# 530        2.24      PE  1596317801
# 535        3.99      EG  1596317802
#
#                                        Hotel Name
# 22                           Hospedaje la Amistad
# 85   Westmark Fairbanks Hotel & Conference Center
# 119                      Canalta Hotel Assiniboia
# 421                                Ataíde Martins
# 465                           محمدالمبروك الاريقط
# 485                           LÜDERITZ NEST HOTEL
# 506
# 508                           Lvye Holiday Resort
# 530               Rancho Santana Horseback Riding
# 535                           Tolip Inn Beni Suef

# %%
# Configure gmaps
#gmaps.configure(api_keys=g_key)
gmaps.configure

# Store latitude and longitude in locations
locations = clean_city_data[["Lat", "Lng"]]

# Fill NaN values and convert to float
humidity = clean_city_data["Humidity"].astype(float)

# Plot heatmap
fig = gmaps.figure(map_type="TERRAIN")

# Create heat layer
heat_layer = gmaps.heatmap_layer(locations, weights=humidity,
                                dissipating=False, max_intensity=0,
                                point_radius=1)                                                                 
# Add layer
fig.add_layer(heat_layer)

# Display figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# NOTE: Do not change any of the code in this cell

# Using the template add the hotel marks to the heatmap
info_box_template = """
<dl>
<dt>Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
</dl>
"""
# Store the DataFrame Row
# NOTE: be sure to update with your DataFrame name
hotel_info = [info_box_template.format(**row) for index, row in hotel_df.iterrows()]
marker_locations = hotel_df[["Lat", "Lng"]]

# %%
# Add marker layer ontop of heat map
#markers = gmaps.marker_layer(locations,
          #info_box_template)                  
#fig.add_layer(markers)

# Display figure

# %%
# Configure gmaps
#gmaps.configure(api_keys=g_key)
gmaps.configure

# Store latitude and longitude in locations
locations = clean_city_data[["Lat", "Lng"]]

# Fill NaN values and convert to float
humidity = clean_city_data["Humidity"].astype(float)

# Plot heatmap
fig = gmaps.figure(map_type="TERRAIN")

# Create heat layer
heat_layer = gmaps.heatmap_layer(locations, weights=humidity,
                                dissipating=False, max_intensity=0,
                                point_radius=1)                                                                 
# Add layer
fig.add_layer(heat_layer)

# Add marker layer ontop of heat map
markers = gmaps.marker_layer(marker_locations,
          info_box_template)                  
fig.add_layer(markers)


# Display figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
